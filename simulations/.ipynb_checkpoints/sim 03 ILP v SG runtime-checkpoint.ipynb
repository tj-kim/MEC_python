# %% [markdown]
# # Simulation 3: ILP vs SG Run Time
#
# TJ Kim
# 8/8/20
#
# Run the third simulation with the following considerations.
#
# - Sweep servers 2, 4, 8
# - Sweep timesteps 2,4,8
# - Overall Users 2,4
# - Record actual run time on python script
#
# Resources: Doesn't matter
# - just make it ample enough that the system doesn't crash

# %%
from IPython.core.debugger import set_trace

# Import Generic Classes
import numpy as np
import copy
import pickle
import random

# Import All Custom Classes
import os, sys
sys.path.append(os.path.pardir+"/classes")
sys.path.append(os.path.pardir+"/solvers")
sys.path.append(os.path.pardir+"/one_mobility")
sys.path.append(os.path.curdir+"/sim_store/sim3")


from Server import *
from User import *
from Link import *
from Job import *
from Migration_Plans import *
from Cost_Recordings import *

from sim3_setting import *

# Import Solver Classes
from Optim_PlanGenerator import *
from SeqGreedy_PlanGenerator import *
from Myopic_PlanGenerator import *
from Naive_PlanGenerator import *

# %% [markdown]
# ### Run Simulation to Measure Time
#
# Set desired counts of each paramter in the simulation.
# Then run the simulation to measure time.

# %%
# Make a collection of tuples to add to list for (u,s,t)
user_count = [1,2,3,4,5]
server_count = [1,2,3,4,5]
time_count = [1,2,3,4,5]

final_list = []

for u in user_count:
    for s in server_count:
        for t in time_count:
            final_list += [(u,s,t)]

# %%
import time

num_trials = 5
ILP_time_stores = {}
SG_time_stores = {}

for (num_user,num_server,time_steps) in final_list:
    ILP_time_stores[(num_user,num_server,time_steps)] = []
    SG_time_stores[(num_user,num_server,time_steps)] = []
    
    for i in range(num_trials):

        print("\nu,s,t:",num_user,num_server,time_steps,"\nTrial Number:",i)

        # Make Users
        users, servers, links, jobs, sim_param = simulation_setting(time_steps,num_server,num_user)

        start = time.time()
        # Make ILP and Optim Prob
        print("Generating Optim_Prob...")
        optim_prob = Optim_PlanGenerator(users, servers, links, jobs, sim_param)
        print("Finished_Generating_prob...")

        # Solve the problem and get the migration plan 
        optim_prob.prob.solve()
        print("Status:", constants.LpStatus[optim_prob.prob.status])
        ILP_mig_plan = Migration_Plans(users, jobs, sim_param) 
        ILP_mig_plan.from_ILP(optim_prob)
        end = time.time()
        
        ILP_time_stores[(num_user,num_server,time_steps)] += [end-start]
        print("ILP runtime:", end-start)

        
        start = time.time()
        # Make SG Prob
        SG_prob = SeqGreedy_PlanGenerator(users, servers, links, jobs, sim_param)
        SG_plan = Migration_Plans(users,jobs,sim_param)
        SG_plan.from_seq_greedy(SG_prob)
        end = time.time()
        
        SG_time_stores[(num_user,num_server,time_steps)] += [end-start]
        print("SG runtime:", end-start)
# Out:
# u,s,t: 1 1 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0362088680267334
# SG runtime: 0.001508474349975586
#
# u,s,t: 1 1 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.014364480972290039
# SG runtime: 0.0005681514739990234
#
# u,s,t: 1 1 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.014295101165771484
# SG runtime: 0.0008249282836914062
#
# u,s,t: 1 1 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.014548778533935547
# SG runtime: 0.0009033679962158203
#
# u,s,t: 1 1 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.014540672302246094
# SG runtime: 0.0006330013275146484
#
# u,s,t: 1 1 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.015113592147827148
# SG runtime: 0.0016331672668457031
#
# u,s,t: 1 1 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01611924171447754
# SG runtime: 0.0016286373138427734
#
# u,s,t: 1 1 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016072511672973633
# SG runtime: 0.0015230178833007812
#
# u,s,t: 1 1 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01500701904296875
# SG runtime: 0.0016112327575683594
#
# u,s,t: 1 1 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01667308807373047
# SG runtime: 0.0016636848449707031
#
# u,s,t: 1 1 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01531529426574707
# SG runtime: 0.0016934871673583984
#
# u,s,t: 1 1 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018095016479492188
# SG runtime: 0.0016622543334960938
#
# u,s,t: 1 1 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.015700340270996094
# SG runtime: 0.0017833709716796875
#
# u,s,t: 1 1 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.015680551528930664
# SG runtime: 0.0016512870788574219
#
# u,s,t: 1 1 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.015456438064575195
# SG runtime: 0.0016210079193115234
#
# u,s,t: 1 1 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.015952110290527344
# SG runtime: 0.0018582344055175781
#
# u,s,t: 1 1 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016590118408203125
# SG runtime: 0.0018341541290283203
#
# u,s,t: 1 1 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016037702560424805
# SG runtime: 0.0017282962799072266
#
# u,s,t: 1 1 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01607203483581543
# SG runtime: 0.0017876625061035156
#
# u,s,t: 1 1 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016250133514404297
# SG runtime: 0.001811981201171875
#
# u,s,t: 1 1 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016511917114257812
# SG runtime: 0.002047300338745117
#
# u,s,t: 1 1 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01629161834716797
# SG runtime: 0.001962900161743164
#
# u,s,t: 1 1 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01625347137451172
# SG runtime: 0.0017077922821044922
#
# u,s,t: 1 1 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016497135162353516
# SG runtime: 0.0019028186798095703
#
# u,s,t: 1 1 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.017104148864746094
# SG runtime: 0.0020127296447753906
#
# u,s,t: 1 2 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.015863418579101562
# SG runtime: 0.0006537437438964844
#
# u,s,t: 1 2 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.015595674514770508
# SG runtime: 0.0010895729064941406
#
# u,s,t: 1 2 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.017728805541992188
# SG runtime: 0.0007472038269042969
#
# u,s,t: 1 2 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01524209976196289
# SG runtime: 0.0006263256072998047
#
# u,s,t: 1 2 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016036272048950195
# SG runtime: 0.0006287097930908203
#
# u,s,t: 1 2 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02603435516357422
# SG runtime: 0.0023686885833740234
#
# u,s,t: 1 2 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01882481575012207
# SG runtime: 0.0019941329956054688
#
# u,s,t: 1 2 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02369070053100586
# SG runtime: 0.0023801326751708984
#
# u,s,t: 1 2 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019353151321411133
# SG runtime: 0.002027273178100586
#
# u,s,t: 1 2 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019578933715820312
# SG runtime: 0.0019500255584716797
#
# u,s,t: 1 2 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.025943517684936523
# SG runtime: 0.003127574920654297
#
# u,s,t: 1 2 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.023656129837036133
# SG runtime: 0.002351999282836914
#
# u,s,t: 1 2 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.021558761596679688
# SG runtime: 0.002295255661010742
#
# u,s,t: 1 2 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02124786376953125
# SG runtime: 0.002306699752807617
#
# u,s,t: 1 2 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.022824525833129883
# SG runtime: 0.0022423267364501953
#
# u,s,t: 1 2 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.024689197540283203
# SG runtime: 0.0025780200958251953
#
# u,s,t: 1 2 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02415180206298828
# SG runtime: 0.002599954605102539
#
# u,s,t: 1 2 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.024213075637817383
# SG runtime: 0.002521991729736328
#
# u,s,t: 1 2 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.024103164672851562
# SG runtime: 0.002602815628051758
#
# u,s,t: 1 2 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02352309226989746
# SG runtime: 0.002346038818359375
#
# u,s,t: 1 2 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02677321434020996
# SG runtime: 0.0029249191284179688
#
# u,s,t: 1 2 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0322422981262207
# SG runtime: 0.003468036651611328
#
# u,s,t: 1 2 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02741265296936035
# SG runtime: 0.0029702186584472656
#
# u,s,t: 1 2 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.026429414749145508
# SG runtime: 0.003729581832885742
#
# u,s,t: 1 2 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03233075141906738
# SG runtime: 0.006021261215209961
#
# u,s,t: 1 3 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01899123191833496
# SG runtime: 0.000978708267211914
#
# u,s,t: 1 3 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.025645017623901367
# SG runtime: 0.0013780593872070312
#
# u,s,t: 1 3 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01931595802307129
# SG runtime: 0.001012563705444336
#
# u,s,t: 1 3 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019237518310546875
# SG runtime: 0.0010287761688232422
#
# u,s,t: 1 3 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02172398567199707
# SG runtime: 0.0009512901306152344
#
# u,s,t: 1 3 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.029454946517944336
# SG runtime: 0.0025687217712402344
#
# u,s,t: 1 3 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03623366355895996
# SG runtime: 0.003589153289794922
#
# u,s,t: 1 3 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.029222965240478516
# SG runtime: 0.0029871463775634766
#
# u,s,t: 1 3 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.028433799743652344
# SG runtime: 0.002866506576538086
#
# u,s,t: 1 3 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.036153554916381836
# SG runtime: 0.003535747528076172
#
# u,s,t: 1 3 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04218029975891113
# SG runtime: 0.0037975311279296875
#
# u,s,t: 1 3 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.041143178939819336
# SG runtime: 0.0038514137268066406
#
# u,s,t: 1 3 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.05273628234863281
# SG runtime: 0.005105257034301758
#
# u,s,t: 1 3 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04598712921142578
# SG runtime: 0.0038557052612304688
#
# u,s,t: 1 3 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04046773910522461
# SG runtime: 0.003748655319213867
#
# u,s,t: 1 3 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.061746835708618164
# SG runtime: 0.0049822330474853516
#
# u,s,t: 1 3 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.054424285888671875
# SG runtime: 0.0047647953033447266
#
# u,s,t: 1 3 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.07043695449829102
# SG runtime: 0.005857944488525391
#
# u,s,t: 1 3 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.05949544906616211
# SG runtime: 0.005205392837524414
#
# u,s,t: 1 3 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.062024831771850586
# SG runtime: 0.0072863101959228516
#
# u,s,t: 1 3 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.07399582862854004
# SG runtime: 0.005959510803222656
#
# u,s,t: 1 3 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08139586448669434
# SG runtime: 0.006263017654418945
#
# u,s,t: 1 3 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0691523551940918
# SG runtime: 0.005915403366088867
#
# u,s,t: 1 3 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08322286605834961
# SG runtime: 0.007363319396972656
#
# u,s,t: 1 3 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.07602357864379883
# SG runtime: 0.00608372688293457
#
# u,s,t: 1 4 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0326535701751709
# SG runtime: 0.0009603500366210938
#
# u,s,t: 1 4 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03303956985473633
# SG runtime: 0.0013735294342041016
#
# u,s,t: 1 4 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03178882598876953
# SG runtime: 0.0013270378112792969
#
# u,s,t: 1 4 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03276705741882324
# SG runtime: 0.0014414787292480469
#
# u,s,t: 1 4 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04037785530090332
# SG runtime: 0.0015933513641357422
#
# u,s,t: 1 4 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08278584480285645
# SG runtime: 0.005300283432006836
#
# u,s,t: 1 4 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0926048755645752
# SG runtime: 0.005405426025390625
#
# u,s,t: 1 4 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0791938304901123
# SG runtime: 0.005121469497680664
#
# u,s,t: 1 4 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08595776557922363
# SG runtime: 0.005234479904174805
#
# u,s,t: 1 4 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.09905099868774414
# SG runtime: 0.00558018684387207
#
# u,s,t: 1 4 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.1395723819732666
# SG runtime: 0.007992744445800781
#
# u,s,t: 1 4 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.16031312942504883
# SG runtime: 0.008596420288085938
#
# u,s,t: 1 4 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.17991328239440918
# SG runtime: 0.007746696472167969
#
# u,s,t: 1 4 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.16965341567993164
# SG runtime: 0.010270357131958008
#
# u,s,t: 1 4 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.15618252754211426
# SG runtime: 0.008504629135131836
#
# u,s,t: 1 4 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.28546667098999023
# SG runtime: 0.010408163070678711
#
# u,s,t: 1 4 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.24384117126464844
# SG runtime: 0.010877847671508789
#
# u,s,t: 1 4 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.31414008140563965
# SG runtime: 0.010543346405029297
#
# u,s,t: 1 4 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.2862060070037842
# SG runtime: 0.010472536087036133
#
# u,s,t: 1 4 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.27300000190734863
# SG runtime: 0.010590314865112305
#
# u,s,t: 1 4 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.4526224136352539
# SG runtime: 0.01259613037109375
#
# u,s,t: 1 4 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.48423242568969727
# SG runtime: 0.013999462127685547
#
# u,s,t: 1 4 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.4575004577636719
# SG runtime: 0.012689352035522461
#
# u,s,t: 1 4 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.3729403018951416
# SG runtime: 0.012717485427856445
#
# u,s,t: 1 4 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.439800500869751
# SG runtime: 0.013609170913696289
#
# u,s,t: 1 5 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.12071847915649414
# SG runtime: 0.002362966537475586
#
# u,s,t: 1 5 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.12044119834899902
# SG runtime: 0.0018398761749267578
#
# u,s,t: 1 5 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.12856626510620117
# SG runtime: 0.0022263526916503906
#
# u,s,t: 1 5 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.13229155540466309
# SG runtime: 0.002942800521850586
#
# u,s,t: 1 5 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.12723588943481445
# SG runtime: 0.0022935867309570312
#
# u,s,t: 1 5 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.6215765476226807
# SG runtime: 0.012079954147338867
#
# u,s,t: 1 5 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.6366255283355713
# SG runtime: 0.013176918029785156
#
# u,s,t: 1 5 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.49568843841552734
# SG runtime: 0.011806726455688477
#
# u,s,t: 1 5 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.49258947372436523
# SG runtime: 0.012084722518920898
#
# u,s,t: 1 5 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.46878600120544434
# SG runtime: 0.011976957321166992
#
# u,s,t: 1 5 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.1576015949249268
# SG runtime: 0.0204012393951416
#
# u,s,t: 1 5 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.274524211883545
# SG runtime: 0.019789695739746094
#
# u,s,t: 1 5 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.2477774620056152
# SG runtime: 0.020273685455322266
#
# u,s,t: 1 5 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.3083271980285645
# SG runtime: 0.01965045928955078
#
# u,s,t: 1 5 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.0009081363677979
# SG runtime: 0.021959543228149414
#
# u,s,t: 1 5 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.118655204772949
# SG runtime: 0.03979635238647461
#
# u,s,t: 1 5 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.680145263671875
# SG runtime: 0.029921531677246094
#
# u,s,t: 1 5 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.467228889465332
# SG runtime: 0.027466773986816406
#
# u,s,t: 1 5 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.482339859008789
# SG runtime: 0.027762174606323242
#
# u,s,t: 1 5 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.0333216190338135
# SG runtime: 0.027956008911132812
#
# u,s,t: 1 5 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 4.27495551109314
# SG runtime: 0.03604292869567871
#
# u,s,t: 1 5 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 4.036494016647339
# SG runtime: 0.03872251510620117
#
# u,s,t: 1 5 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 3.1253013610839844
# SG runtime: 0.03589153289794922
#
# u,s,t: 1 5 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 3.751373767852783
# SG runtime: 0.035703420639038086
#
# u,s,t: 1 5 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 3.520813465118408
# SG runtime: 0.035546302795410156
#
# u,s,t: 2 1 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02670741081237793
# SG runtime: 0.001458883285522461
#
# u,s,t: 2 1 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016964197158813477
# SG runtime: 0.0011391639709472656
#
# u,s,t: 2 1 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016309738159179688
# SG runtime: 0.0011086463928222656
#
# u,s,t: 2 1 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016977310180664062
# SG runtime: 0.0011429786682128906
#
# u,s,t: 2 1 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016074657440185547
# SG runtime: 0.0011491775512695312
#
# u,s,t: 2 1 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016998767852783203
# SG runtime: 0.0022978782653808594
#
# u,s,t: 2 1 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016938447952270508
# SG runtime: 0.002214193344116211
#
# u,s,t: 2 1 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.017000913619995117
# SG runtime: 0.002195119857788086
#
# u,s,t: 2 1 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.016589641571044922
# SG runtime: 0.0023555755615234375
#
# u,s,t: 2 1 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.017244815826416016
# SG runtime: 0.0021696090698242188
#
# u,s,t: 2 1 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01771855354309082
# SG runtime: 0.0022330284118652344
#
# u,s,t: 2 1 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01755547523498535
# SG runtime: 0.002357959747314453
#
# u,s,t: 2 1 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01732945442199707
# SG runtime: 0.002355337142944336
#
# u,s,t: 2 1 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.017702341079711914
# SG runtime: 0.0024318695068359375
#
# u,s,t: 2 1 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.017499446868896484
# SG runtime: 0.002346038818359375
#
# u,s,t: 2 1 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018416643142700195
# SG runtime: 0.002580881118774414
#
# u,s,t: 2 1 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0180666446685791
# SG runtime: 0.0027129650115966797
#
# u,s,t: 2 1 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01890397071838379
# SG runtime: 0.002602815628051758
#
# u,s,t: 2 1 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01824188232421875
# SG runtime: 0.0025882720947265625
#
# u,s,t: 2 1 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018488645553588867
# SG runtime: 0.0025339126586914062
#
# u,s,t: 2 1 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01883983612060547
# SG runtime: 0.0028121471405029297
#
# u,s,t: 2 1 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019388675689697266
# SG runtime: 0.0026383399963378906
#
# u,s,t: 2 1 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019110679626464844
# SG runtime: 0.0027489662170410156
#
# u,s,t: 2 1 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019199609756469727
# SG runtime: 0.0028285980224609375
#
# u,s,t: 2 1 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01922321319580078
# SG runtime: 0.0028188228607177734
#
# u,s,t: 2 2 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019095420837402344
# SG runtime: 0.0011858940124511719
#
# u,s,t: 2 2 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.017732858657836914
# SG runtime: 0.0008885860443115234
#
# u,s,t: 2 2 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01811051368713379
# SG runtime: 0.001215219497680664
#
# u,s,t: 2 2 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018606185913085938
# SG runtime: 0.0011887550354003906
#
# u,s,t: 2 2 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01822948455810547
# SG runtime: 0.0008678436279296875
#
# u,s,t: 2 2 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02338242530822754
# SG runtime: 0.0029675960540771484
#
# u,s,t: 2 2 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02330183982849121
# SG runtime: 0.0029675960540771484
#
# u,s,t: 2 2 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.023509502410888672
# SG runtime: 0.0028312206268310547
#
# u,s,t: 2 2 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.023032188415527344
# SG runtime: 0.002916574478149414
#
# u,s,t: 2 2 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.023569583892822266
# SG runtime: 0.0029120445251464844
#
# u,s,t: 2 2 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.028095245361328125
# SG runtime: 0.0035834312438964844
#
# u,s,t: 2 2 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.027618885040283203
# SG runtime: 0.0035147666931152344
#
# u,s,t: 2 2 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.027594566345214844
# SG runtime: 0.003709077835083008
#
# u,s,t: 2 2 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.027788400650024414
# SG runtime: 0.003533601760864258
#
# u,s,t: 2 2 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.028090715408325195
# SG runtime: 0.003551959991455078
#
# u,s,t: 2 2 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03165721893310547
# SG runtime: 0.004190206527709961
#
# u,s,t: 2 2 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03244924545288086
# SG runtime: 0.004256248474121094
#
# u,s,t: 2 2 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03159189224243164
# SG runtime: 0.004220247268676758
#
# u,s,t: 2 2 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03405141830444336
# SG runtime: 0.004280567169189453
#
# u,s,t: 2 2 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03240704536437988
# SG runtime: 0.004472255706787109
#
# u,s,t: 2 2 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.036718130111694336
# SG runtime: 0.004846096038818359
#
# u,s,t: 2 2 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04089713096618652
# SG runtime: 0.0050754547119140625
#
# u,s,t: 2 2 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03708982467651367
# SG runtime: 0.005055665969848633
#
# u,s,t: 2 2 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.038015127182006836
# SG runtime: 0.004786014556884766
#
# u,s,t: 2 2 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03544473648071289
# SG runtime: 0.0046215057373046875
#
# u,s,t: 2 3 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.024319887161254883
# SG runtime: 0.001417398452758789
#
# u,s,t: 2 3 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.023680925369262695
# SG runtime: 0.0009543895721435547
#
# u,s,t: 2 3 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.023944854736328125
# SG runtime: 0.0009784698486328125
#
# u,s,t: 2 3 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.023828744888305664
# SG runtime: 0.0012776851654052734
#
# u,s,t: 2 3 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.024486541748046875
# SG runtime: 0.001355886459350586
#
# u,s,t: 2 3 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.043241262435913086
# SG runtime: 0.00461578369140625
#
# u,s,t: 2 3 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.042952537536621094
# SG runtime: 0.004701137542724609
#
# u,s,t: 2 3 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04363894462585449
# SG runtime: 0.005040407180786133
#
# u,s,t: 2 3 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.040497541427612305
# SG runtime: 0.0044362545013427734
#
# u,s,t: 2 3 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.042685747146606445
# SG runtime: 0.004595041275024414
#
# u,s,t: 2 3 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.07054781913757324
# SG runtime: 0.006787776947021484
#
# u,s,t: 2 3 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.06251287460327148
# SG runtime: 0.0070493221282958984
#
# u,s,t: 2 3 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.06631112098693848
# SG runtime: 0.006497383117675781
#
# u,s,t: 2 3 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.06181836128234863
# SG runtime: 0.006742238998413086
#
# u,s,t: 2 3 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.06382465362548828
# SG runtime: 0.006602048873901367
#
# u,s,t: 2 3 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.10268211364746094
# SG runtime: 0.008630990982055664
#
# u,s,t: 2 3 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.09749531745910645
# SG runtime: 0.008603811264038086
#
# u,s,t: 2 3 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.09898781776428223
# SG runtime: 0.008501291275024414
#
# u,s,t: 2 3 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0988461971282959
# SG runtime: 0.00845646858215332
#
# u,s,t: 2 3 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.10495853424072266
# SG runtime: 0.00885152816772461
#
# u,s,t: 2 3 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.14980554580688477
# SG runtime: 0.010585308074951172
#
# u,s,t: 2 3 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.14192891120910645
# SG runtime: 0.010094881057739258
#
# u,s,t: 2 3 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.13603544235229492
# SG runtime: 0.010151147842407227
#
# u,s,t: 2 3 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.14638352394104004
# SG runtime: 0.010314464569091797
#
# u,s,t: 2 3 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.146775484085083
# SG runtime: 0.009945869445800781
#
# u,s,t: 2 4 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.05118823051452637
# SG runtime: 0.0017404556274414062
#
# u,s,t: 2 4 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.051743268966674805
# SG runtime: 0.0015239715576171875
#
# u,s,t: 2 4 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.05091357231140137
# SG runtime: 0.0015325546264648438
#
# u,s,t: 2 4 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.05092811584472656
# SG runtime: 0.0015370845794677734
#
# u,s,t: 2 4 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.05217862129211426
# SG runtime: 0.0020492076873779297
#
# u,s,t: 2 4 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.1501462459564209
# SG runtime: 0.009193658828735352
#
# u,s,t: 2 4 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.15864253044128418
# SG runtime: 0.009206771850585938
#
# u,s,t: 2 4 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.1729588508605957
# SG runtime: 0.008816242218017578
#
# u,s,t: 2 4 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.16385483741760254
# SG runtime: 0.009115934371948242
#
# u,s,t: 2 4 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.16462492942810059
# SG runtime: 0.009040594100952148
#
# u,s,t: 2 4 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.3198227882385254
# SG runtime: 0.013906240463256836
#
# u,s,t: 2 4 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.32383084297180176
# SG runtime: 0.013620376586914062
#
# u,s,t: 2 4 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.29927706718444824
# SG runtime: 0.01414942741394043
#
# u,s,t: 2 4 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.3450052738189697
# SG runtime: 0.013670206069946289
#
# u,s,t: 2 4 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.3250300884246826
# SG runtime: 0.013767242431640625
#
# u,s,t: 2 4 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.589594841003418
# SG runtime: 0.019878387451171875
#
# u,s,t: 2 4 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.6008691787719727
# SG runtime: 0.01972341537475586
#
# u,s,t: 2 4 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.6109621524810791
# SG runtime: 0.020404815673828125
#
# u,s,t: 2 4 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.5755863189697266
# SG runtime: 0.021070003509521484
#
# u,s,t: 2 4 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.49669742584228516
# SG runtime: 0.018340349197387695
#
# u,s,t: 2 4 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.8286142349243164
# SG runtime: 0.02362823486328125
#
# u,s,t: 2 4 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.9378185272216797
# SG runtime: 0.02408623695373535
#
# u,s,t: 2 4 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.8115484714508057
# SG runtime: 0.023634672164916992
#
# u,s,t: 2 4 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.8185346126556396
# SG runtime: 0.023583173751831055
#
# u,s,t: 2 4 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.8331944942474365
# SG runtime: 0.024024486541748047
#
# u,s,t: 2 5 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.28038501739501953
# SG runtime: 0.0026743412017822266
#
# u,s,t: 2 5 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.27920103073120117
# SG runtime: 0.0019893646240234375
#
# u,s,t: 2 5 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.27835822105407715
# SG runtime: 0.002496480941772461
#
# u,s,t: 2 5 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.27988696098327637
# SG runtime: 0.0035469532012939453
#
# u,s,t: 2 5 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.276364803314209
# SG runtime: 0.002415180206298828
#
# u,s,t: 2 5 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.1837902069091797
# SG runtime: 0.022169113159179688
#
# u,s,t: 2 5 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.2034821510314941
# SG runtime: 0.021857500076293945
#
# u,s,t: 2 5 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.182755708694458
# SG runtime: 0.0220334529876709
#
# u,s,t: 2 5 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.2329235076904297
# SG runtime: 0.02953791618347168
#
# u,s,t: 2 5 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.1980223655700684
# SG runtime: 0.027750492095947266
#
# u,s,t: 2 5 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.534196138381958
# SG runtime: 0.041383981704711914
#
# u,s,t: 2 5 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 3.1026177406311035
# SG runtime: 0.04206085205078125
#
# u,s,t: 2 5 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.7444710731506348
# SG runtime: 0.04086494445800781
#
# u,s,t: 2 5 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.982750654220581
# SG runtime: 0.03832292556762695
#
# u,s,t: 2 5 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.5693540573120117
# SG runtime: 0.03848147392272949
#
# u,s,t: 2 5 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 4.330579042434692
# SG runtime: 0.052930355072021484
#
# u,s,t: 2 5 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 5.255813837051392
# SG runtime: 0.05332231521606445
#
# u,s,t: 2 5 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 5.183564186096191
# SG runtime: 0.053227901458740234
#
# u,s,t: 2 5 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 4.502928972244263
# SG runtime: 0.052781105041503906
#
# u,s,t: 2 5 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 5.1377012729644775
# SG runtime: 0.053359031677246094
#
# u,s,t: 2 5 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 6.80026650428772
# SG runtime: 0.069091796875
#
# u,s,t: 2 5 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 7.877932071685791
# SG runtime: 0.06967377662658691
#
# u,s,t: 2 5 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 7.969531059265137
# SG runtime: 0.06858015060424805
#
# u,s,t: 2 5 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 7.483941316604614
# SG runtime: 0.07010960578918457
#
# u,s,t: 2 5 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 7.016248464584351
# SG runtime: 0.06959176063537598
#
# u,s,t: 3 1 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03775191307067871
# SG runtime: 0.002316713333129883
#
# u,s,t: 3 1 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018754005432128906
# SG runtime: 0.0013706684112548828
#
# u,s,t: 3 1 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018544912338256836
# SG runtime: 0.0010058879852294922
#
# u,s,t: 3 1 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018331289291381836
# SG runtime: 0.0013918876647949219
#
# u,s,t: 3 1 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.018584012985229492
# SG runtime: 0.0013899803161621094
#
# u,s,t: 3 1 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.020263195037841797
# SG runtime: 0.0029573440551757812
#
# u,s,t: 3 1 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019530057907104492
# SG runtime: 0.002716541290283203
#
# u,s,t: 3 1 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019437551498413086
# SG runtime: 0.0027883052825927734
#
# u,s,t: 3 1 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019678354263305664
# SG runtime: 0.0026903152465820312
#
# u,s,t: 3 1 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.01969289779663086
# SG runtime: 0.002808809280395508
#
# u,s,t: 3 1 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.020735740661621094
# SG runtime: 0.003194570541381836
#
# u,s,t: 3 1 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02034735679626465
# SG runtime: 0.0030803680419921875
#
# u,s,t: 3 1 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02092456817626953
# SG runtime: 0.0031397342681884766
#
# u,s,t: 3 1 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.019941091537475586
# SG runtime: 0.003229379653930664
#
# u,s,t: 3 1 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02020263671875
# SG runtime: 0.0032532215118408203
#
# u,s,t: 3 1 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02149343490600586
# SG runtime: 0.003473997116088867
#
# u,s,t: 3 1 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02155756950378418
# SG runtime: 0.003442049026489258
#
# u,s,t: 3 1 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02134227752685547
# SG runtime: 0.0034780502319335938
#
# u,s,t: 3 1 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.022053003311157227
# SG runtime: 0.0034317970275878906
#
# u,s,t: 3 1 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02108144760131836
# SG runtime: 0.003292083740234375
#
# u,s,t: 3 1 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.022181272506713867
# SG runtime: 0.003762483596801758
#
# u,s,t: 3 1 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.022410869598388672
# SG runtime: 0.0036978721618652344
#
# u,s,t: 3 1 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02246856689453125
# SG runtime: 0.0036520957946777344
#
# u,s,t: 3 1 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.022606849670410156
# SG runtime: 0.0038917064666748047
#
# u,s,t: 3 1 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.022635936737060547
# SG runtime: 0.0037393569946289062
#
# u,s,t: 3 2 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.021083831787109375
# SG runtime: 0.0011970996856689453
#
# u,s,t: 3 2 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.020915508270263672
# SG runtime: 0.0011477470397949219
#
# u,s,t: 3 2 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02077770233154297
# SG runtime: 0.001519918441772461
#
# u,s,t: 3 2 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.020769119262695312
# SG runtime: 0.0014753341674804688
#
# u,s,t: 3 2 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.020829200744628906
# SG runtime: 0.001238107681274414
#
# u,s,t: 3 2 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.028056859970092773
# SG runtime: 0.0041103363037109375
#
# u,s,t: 3 2 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02706623077392578
# SG runtime: 0.0037758350372314453
#
# u,s,t: 3 2 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02714848518371582
# SG runtime: 0.0038089752197265625
#
# u,s,t: 3 2 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.026991605758666992
# SG runtime: 0.0038280487060546875
#
# u,s,t: 3 2 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.027411222457885742
# SG runtime: 0.003802776336669922
#
# u,s,t: 3 2 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03293490409851074
# SG runtime: 0.004862070083618164
#
# u,s,t: 3 2 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03283381462097168
# SG runtime: 0.004866123199462891
#
# u,s,t: 3 2 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03400373458862305
# SG runtime: 0.005030155181884766
#
# u,s,t: 3 2 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ...
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.02858114242553711
# SG runtime: 0.0018460750579833984
#
# u,s,t: 5 2 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0368046760559082
# SG runtime: 0.002058267593383789
#
# u,s,t: 5 2 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.03825545310974121
# SG runtime: 0.007927179336547852
#
# u,s,t: 5 2 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04829716682434082
# SG runtime: 0.010433435440063477
#
# u,s,t: 5 2 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04166531562805176
# SG runtime: 0.005879878997802734
#
# u,s,t: 5 2 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04420614242553711
# SG runtime: 0.007269382476806641
#
# u,s,t: 5 2 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.042430877685546875
# SG runtime: 0.006630420684814453
#
# u,s,t: 5 2 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08071398735046387
# SG runtime: 0.009997844696044922
#
# u,s,t: 5 2 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.060791969299316406
# SG runtime: 0.008964300155639648
#
# u,s,t: 5 2 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.09121441841125488
# SG runtime: 0.014669656753540039
#
# u,s,t: 5 2 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.11362171173095703
# SG runtime: 0.011137008666992188
#
# u,s,t: 5 2 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.07706379890441895
# SG runtime: 0.009521961212158203
#
# u,s,t: 5 2 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.09376645088195801
# SG runtime: 0.012394189834594727
#
# u,s,t: 5 2 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08295297622680664
# SG runtime: 0.010332822799682617
#
# u,s,t: 5 2 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.07362198829650879
# SG runtime: 0.01003265380859375
#
# u,s,t: 5 2 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08476424217224121
# SG runtime: 0.013910770416259766
#
# u,s,t: 5 2 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.11105918884277344
# SG runtime: 0.012430429458618164
#
# u,s,t: 5 2 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.10264444351196289
# SG runtime: 0.01744985580444336
#
# u,s,t: 5 2 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.12129974365234375
# SG runtime: 0.011190652847290039
#
# u,s,t: 5 2 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08247756958007812
# SG runtime: 0.014663457870483398
#
# u,s,t: 5 2 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.07321667671203613
# SG runtime: 0.012191295623779297
#
# u,s,t: 5 2 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.08823013305664062
# SG runtime: 0.011533260345458984
#
# u,s,t: 5 3 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.060976505279541016
# SG runtime: 0.0021865367889404297
#
# u,s,t: 5 3 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04854297637939453
# SG runtime: 0.0021381378173828125
#
# u,s,t: 5 3 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04819965362548828
# SG runtime: 0.0022170543670654297
#
# u,s,t: 5 3 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.045543670654296875
# SG runtime: 0.002000570297241211
#
# u,s,t: 5 3 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.04400134086608887
# SG runtime: 0.0025103092193603516
#
# u,s,t: 5 3 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.09431099891662598
# SG runtime: 0.010450363159179688
#
# u,s,t: 5 3 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.10065007209777832
# SG runtime: 0.010901451110839844
#
# u,s,t: 5 3 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.10462641716003418
# SG runtime: 0.010816812515258789
#
# u,s,t: 5 3 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.0988469123840332
# SG runtime: 0.011240005493164062
#
# u,s,t: 5 3 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.09424185752868652
# SG runtime: 0.011280298233032227
#
# u,s,t: 5 3 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.17906785011291504
# SG runtime: 0.014875411987304688
#
# u,s,t: 5 3 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.18789172172546387
# SG runtime: 0.016044139862060547
#
# u,s,t: 5 3 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.17394590377807617
# SG runtime: 0.016415834426879883
#
# u,s,t: 5 3 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.1743624210357666
# SG runtime: 0.014541864395141602
#
# u,s,t: 5 3 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.17738986015319824
# SG runtime: 0.015480518341064453
#
# u,s,t: 5 3 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.2954444885253906
# SG runtime: 0.03662586212158203
#
# u,s,t: 5 3 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.28214454650878906
# SG runtime: 0.022279739379882812
#
# u,s,t: 5 3 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.2758324146270752
# SG runtime: 0.02458333969116211
#
# u,s,t: 5 3 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.3353276252746582
# SG runtime: 0.025681018829345703
#
# u,s,t: 5 3 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.22582268714904785
# SG runtime: 0.020112037658691406
#
# u,s,t: 5 3 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.47638511657714844
# SG runtime: 0.036237239837646484
#
# u,s,t: 5 3 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.4330170154571533
# SG runtime: 0.030208349227905273
#
# u,s,t: 5 3 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.37261390686035156
# SG runtime: 0.029143095016479492
#
# u,s,t: 5 3 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.39356350898742676
# SG runtime: 0.027193784713745117
#
# u,s,t: 5 3 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.4291718006134033
# SG runtime: 0.02541041374206543
#
# u,s,t: 5 4 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.14055752754211426
# SG runtime: 0.0028886795043945312
#
# u,s,t: 5 4 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.15019869804382324
# SG runtime: 0.0026769638061523438
#
# u,s,t: 5 4 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.18050551414489746
# SG runtime: 0.0022051334381103516
#
# u,s,t: 5 4 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.1676337718963623
# SG runtime: 0.003000497817993164
#
# u,s,t: 5 4 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.1655113697052002
# SG runtime: 0.0022764205932617188
#
# u,s,t: 5 4 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.5393478870391846
# SG runtime: 0.02155590057373047
#
# u,s,t: 5 4 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.45581889152526855
# SG runtime: 0.020364046096801758
#
# u,s,t: 5 4 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.48372960090637207
# SG runtime: 0.02054762840270996
#
# u,s,t: 5 4 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.47329092025756836
# SG runtime: 0.023712635040283203
#
# u,s,t: 5 4 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.5007548332214355
# SG runtime: 0.02193474769592285
#
# u,s,t: 5 4 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.0054633617401123
# SG runtime: 0.03410744667053223
#
# u,s,t: 5 4 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.9525313377380371
# SG runtime: 0.03476381301879883
#
# u,s,t: 5 4 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.9528882503509521
# SG runtime: 0.0346221923828125
#
# u,s,t: 5 4 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.0145633220672607
# SG runtime: 0.032418251037597656
#
# u,s,t: 5 4 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 0.9096229076385498
# SG runtime: 0.03452563285827637
#
# u,s,t: 5 4 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.6344780921936035
# SG runtime: 0.04816460609436035
#
# u,s,t: 5 4 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.685776710510254
# SG runtime: 0.05831742286682129
#
# u,s,t: 5 4 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.9873642921447754
# SG runtime: 0.05564594268798828
#
# u,s,t: 5 4 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.7919502258300781
# SG runtime: 0.04471850395202637
#
# u,s,t: 5 4 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.5894696712493896
# SG runtime: 0.04505300521850586
#
# u,s,t: 5 4 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.6315524578094482
# SG runtime: 0.06437277793884277
#
# u,s,t: 5 4 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.621345281600952
# SG runtime: 0.057359933853149414
#
# u,s,t: 5 4 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.4601664543151855
# SG runtime: 0.0805063247680664
#
# u,s,t: 5 4 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 2.9246788024902344
# SG runtime: 0.0668482780456543
#
# u,s,t: 5 4 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 3.3300085067749023
# SG runtime: 0.08500075340270996
#
# u,s,t: 5 5 1
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.3334224224090576
# SG runtime: 0.0034322738647460938
#
# u,s,t: 5 5 1
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.315981149673462
# SG runtime: 0.0031287670135498047
#
# u,s,t: 5 5 1
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.2795991897583008
# SG runtime: 0.0030612945556640625
#
# u,s,t: 5 5 1
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.1980860233306885
# SG runtime: 0.005059719085693359
#
# u,s,t: 5 5 1
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 1.2088899612426758
# SG runtime: 0.0032150745391845703
#
# u,s,t: 5 5 2
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 5.340948820114136
# SG runtime: 0.05452728271484375
#
# u,s,t: 5 5 2
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 5.692619323730469
# SG runtime: 0.0552675724029541
#
# u,s,t: 5 5 2
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 4.772771596908569
# SG runtime: 0.052591562271118164
#
# u,s,t: 5 5 2
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 4.682761907577515
# SG runtime: 0.055576324462890625
#
# u,s,t: 5 5 2
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 4.806438207626343
# SG runtime: 0.054749250411987305
#
# u,s,t: 5 5 3
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 10.743102312088013
# SG runtime: 0.09183382987976074
#
# u,s,t: 5 5 3
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 11.169057369232178
# SG runtime: 0.09264397621154785
#
# u,s,t: 5 5 3
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 11.137396812438965
# SG runtime: 0.09303736686706543
#
# u,s,t: 5 5 3
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 10.81479001045227
# SG runtime: 0.09104228019714355
#
# u,s,t: 5 5 3
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 10.816515922546387
# SG runtime: 0.09126138687133789
#
# u,s,t: 5 5 4
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 17.78756546974182
# SG runtime: 0.1287848949432373
#
# u,s,t: 5 5 4
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 19.671958208084106
# SG runtime: 0.13144421577453613
#
# u,s,t: 5 5 4
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 20.057182788848877
# SG runtime: 0.12977218627929688
#
# u,s,t: 5 5 4
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 18.884584665298462
# SG runtime: 0.1298975944519043
#
# u,s,t: 5 5 4
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 19.833871841430664
# SG runtime: 0.13999462127685547
#
# u,s,t: 5 5 5
# Trial Number: 0
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 33.54925537109375
# SG runtime: 0.18854403495788574
#
# u,s,t: 5 5 5
# Trial Number: 1
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 34.26280403137207
# SG runtime: 0.19448399543762207
#
# u,s,t: 5 5 5
# Trial Number: 2
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 31.724814414978027
# SG runtime: 0.1751260757446289
#
# u,s,t: 5 5 5
# Trial Number: 3
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 33.73115134239197
# SG runtime: 0.17259597778320312
#
# u,s,t: 5 5 5
# Trial Number: 4
# Generating Optim_Prob...
# Finished_Generating_prob...
# Status: Optimal
# ILP runtime: 32.5024995803833
# SG runtime: 0.1730341911315918

# %% [markdown]
# ### Find Mean run times in seconds for desired value
#
# u = 2,4
# s = 1 to 4
# t = 1 to 4
#
# Split ILP and SG

# %%
final_print = np.zeros((8,8))
x_idx = 0
y_idx = 0

user_count = [2,4]
server_count = [1,2,3,4]
time_count = [1,2,3,4]


for s in server_count:
    for u in user_count:
        for t in time_count:
            
            # Record ILP
            val = np.mean(ILP_time_stores[(u,s,t)])
            final_print[y_idx,x_idx] = val
            x_idx += 1
            
            # Record SG
            val = np.mean(SG_time_stores[(u,s,t)])
            final_print[y_idx,x_idx] = val
            x_idx += 1
            
        y_idx += 1
        x_idx = 0

# %%
np.set_printoptions(precision=2)
print(final_print)
# Out:
# [[1.86e-02 1.20e-03 1.70e-02 2.25e-03 1.76e-02 2.34e-03 1.84e-02 2.60e-03]
#  [2.79e-02 1.91e-03 2.11e-02 3.35e-03 2.45e-02 4.10e-03 4.75e-02 5.72e-03]
#  [1.84e-02 1.07e-03 2.34e-02 2.92e-03 2.78e-02 3.58e-03 3.24e-02 4.28e-03]
#  [2.51e-02 1.63e-03 3.40e-02 5.38e-03 4.18e-02 6.38e-03 5.75e-02 8.46e-03]
#  [2.41e-02 1.20e-03 4.26e-02 4.68e-03 6.50e-02 6.74e-03 1.01e-01 8.61e-03]
#  [3.56e-02 1.85e-03 7.68e-02 9.07e-03 1.29e-01 1.27e-02 2.00e-01 1.60e-02]
#  [5.14e-02 1.68e-03 1.62e-01 9.07e-03 3.23e-01 1.38e-02 5.75e-01 1.99e-02]
#  [9.87e-02 2.00e-03 3.32e-01 1.63e-02 7.54e-01 2.70e-02 1.24e+00 3.58e-02]]
