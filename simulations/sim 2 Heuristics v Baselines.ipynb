# %% [markdown]
# # Simulation 2: Heuristics vs. Baselines
#
# TJ Kim
# 8/7/20
#
# Run the second simulation with the following considerations.
#
# - 10 Servers, 20 TS, 15 Users
# - Use ONE-mobility
# - Job lengths: vr = 10-15, Assist = 5-10, AR = 10-15
# - We share the same users and jobs between simulations
#
# Resources: Normal
# - All jobs are run with standard Quantity
# - 14 level 1, 5 level 2, 1 level 3

# %%
from IPython.core.debugger import set_trace

# Import Generic Classes
import numpy as np
import copy
import pickle
import random

# Import All Custom Classes
import os, sys
sys.path.append(os.path.pardir+"/classes")
sys.path.append(os.path.pardir+"/solvers")
sys.path.append(os.path.pardir+"/one_mobility")
sys.path.append(os.path.curdir + "/sim_store/sim2")


from Server import *
from User import *
from Link import *
from Job import *
from Migration_Plans import *
from Cost_Recordings import *

from sim2_setting import *
from sim2_setting_ample import *

# Import Solver Classes
from Optim_PlanGenerator import *
from SeqGreedy_PlanGenerator import *
from Myopic_PlanGenerator import *
from Naive_PlanGenerator import *
from Cloud_PlanGenerator import *

# %% [markdown]
# ### Run Simulation across 10 trials for the groups
#
# Heuristics - Sequential Greedy and Batched

# %%
num_trials = 10
Batch_cost_stores = []
SG_cost_stores = []
Naive_cost_stores = []
Myopic_cost_stores = []
Cloud_cost_stores = []

Batch_cost_stores_ample = []
SG_cost_stores_ample = []
Naive_cost_stores_ample = []
Myopic_cost_stores_ample = []
Cloud_cost_stores_ample = []

for i in range(num_trials):
    
    print("Trial Number:",i)
    
    print("limited")
        
    while True:
        try:
            # Make Users
            users, servers, links, jobs, sim_param = simulation_setting()
            # Make Batch Prob 
            print("batch_prob...")
            Batch_prob = SeqGreedy_PlanGenerator(users, servers, links, jobs, sim_param)
            Batch_plan = Migration_Plans(users,jobs,sim_param)
            Batch_plan.from_seq_greedy(Batch_prob)
            Batch_cost_stores += [Cost_Recordings(Batch_plan)]
            print("done!")
            break
        except:
            print("batch_broken, repeating with new users")
            continue
        
    
    # Make SG Prob
    # Set Refresh to false for SG
    refresh_rate = [0,0]
    refresh = False

    jobs2 = copy.deepcopy(jobs)
    for j in range(len(jobs2)):
        jobs2[j].info_from_usr(users[j],refresh_rate,refresh)
    
    print("SG prob...")
    SG_prob = SeqGreedy_PlanGenerator(users, servers, links, jobs2, sim_param)
    SG_plan = Migration_Plans(users,jobs2,sim_param)
    SG_plan.from_seq_greedy(SG_prob)
    SG_cost_stores += [Cost_Recordings(SG_plan)]
    print("done!")
    
    # Make Cloud Prob
    print("Cloud prob...")
    Cloud_prob = Cloud_PlanGenerator(users, servers, links, jobs, sim_param)
    Cloud_plan = Migration_Plans(users,jobs,sim_param)
    Cloud_plan.from_seq_greedy(Cloud_prob)
    Cloud_cost_stores += [Cost_Recordings(Cloud_plan)]
    print("done!")
    
    # Make Naive Prob
    print("Naive prob...")
    Naive_prob = Naive_PlanGenerator(users, servers, links, jobs, sim_param)
    Naive_plan = Migration_Plans(users,jobs,sim_param)
    Naive_plan.from_seq_greedy(Naive_prob)
    Naive_cost_stores += [Cost_Recordings(Naive_plan)]
    print("done!")
    
    # Make Myopic Prob
    print("Myopic prob...")
    Myopic_prob = Myopic_PlanGenerator(users, servers, links, jobs, sim_param)
    Myopic_plan = Migration_Plans(users,jobs,sim_param)
    Myopic_plan.from_seq_greedy(Myopic_prob)
    Myopic_cost_stores += [Cost_Recordings(Myopic_plan)]
    print("done!")
    
    print("ample")
    # Make Servers Ample and Run again
    for s in servers:
        s.avail_rsrc = np.ones(s.avail_rsrc.shape) * 1000
        
    # Make Batch Prob
    print("batch_prob...")
    Batch_prob = SeqGreedy_PlanGenerator(users, servers, links, jobs, sim_param)
    Batch_plan = Migration_Plans(users,jobs,sim_param)
    Batch_plan.from_seq_greedy(Batch_prob)
    Batch_cost_stores_ample += [Cost_Recordings(Batch_plan)]
    print("done!")
    
    # Make SG Prob
    print("SG prob...")
    SG_prob = SeqGreedy_PlanGenerator(users, servers, links, jobs2, sim_param)
    SG_plan = Migration_Plans(users,jobs2,sim_param)
    SG_plan.from_seq_greedy(SG_prob)
    SG_cost_stores_ample += [Cost_Recordings(SG_plan)]
    print("done!")
    
    # Make Cloud Prob
    print("Cloud prob...")
    Cloud_prob = Cloud_PlanGenerator(users, servers, links, jobs, sim_param)
    Cloud_plan = Migration_Plans(users,jobs,sim_param)
    Cloud_plan.from_seq_greedy(Cloud_prob)
    Cloud_cost_stores_ample += [Cost_Recordings(Cloud_plan)]
    print("done!")
    
    # Make Naive Prob
    print("Naive prob...")
    Naive_prob = Naive_PlanGenerator(users, servers, links, jobs, sim_param)
    Naive_plan = Migration_Plans(users,jobs,sim_param)
    Naive_plan.from_seq_greedy(Naive_prob)
    Naive_cost_stores_ample += [Cost_Recordings(Naive_plan)]
    print("done!")
    
    # Make Myopic Prob
    print("Myopic prob...")
    Myopic_prob = Myopic_PlanGenerator(users, servers, links, jobs, sim_param)
    Myopic_plan = Migration_Plans(users,jobs,sim_param)
    Myopic_plan.from_seq_greedy(Myopic_prob)
    Myopic_cost_stores_ample += [Cost_Recordings(Myopic_plan)]
    print("done!")
# Out:
# Trial Number: 0
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 0 4 4
# Struck Placement Resource (j,s,t): 3 4 4
# Struck Placement Resource (j,s,t): 3 4 5
# Struck Placement Resource (j,s,t): 4 4 5
# Struck Placement Resource (j,s,t): 4 4 4
# not enough resources, simulation broken
# batch_broken, repeating with new users
# batch_prob...
# Struck Placement Resource (j,s,t): 17 4 2
# Struck Placement Resource (j,s,t): 17 4 3
# Struck Placement Resource (j,s,t): 17 4 4
# Struck Placement Resource (j,s,t): 1 0 5
# Struck Placement Resource (j,s,t): 10 4 4
# Struck Placement Resource (j,s,t): 12 8 5
# Struck Placement Resource (j,s,t): 7 8 6
# Struck Placement Resource (j,s,t): 11 8 6
# Struck Placement Resource (j,s,t): 14 8 6
# Struck Placement Resource (j,s,t): 14 0 6
# Struck Placement Resource (j,s,t): 14 0 7
# Struck Placement Resource (j,s,t): 10 1 7
# Struck Placement Resource (j,s,t): 13 4 7
# Struck Placement Resource (j,s,t): 13 8 7
# Struck Placement Resource (j,s,t): 17 4 7
# Struck Placement Resource (j,s,t): 17 8 7
# Struck Placement Resource (j,s,t): 17 8 8
# Struck Placement Resource (j,s,t): 17 4 8
# Struck Placement Resource (j,s,t): 17 8 6
# not enough resources, simulation broken
# batch_broken, repeating with new users
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# Struck Placement Resource (j,s,t): 14 1 3
# Struck Placement Resource (j,s,t): 14 1 4
# Struck Placement Resource (j,s,t): 14 1 5
# Struck Placement Resource (j,s,t): 14 1 6
# Struck Placement Resource (j,s,t): 14 1 7
# Struck Placement Resource (j,s,t): 14 1 8
# Struck Placement Resource (j,s,t): 14 1 9
# Struck Placement Resource (j,s,t): 1 1 4
# Struck Placement Resource (j,s,t): 1 1 5
# Struck Placement Resource (j,s,t): 1 1 6
# Struck Placement Resource (j,s,t): 1 1 7
# Struck Placement Resource (j,s,t): 1 1 8
# Struck Placement Resource (j,s,t): 1 1 9
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 6 4 3
# Struck Placement Resource (j,s,t): 9 4 3
# Struck Placement Resource (j,s,t): 10 4 4
# Struck Placement Resource (j,s,t): 13 4 4
# Struck Placement Resource (j,s,t): 18 3 4
# Struck Placement Resource (j,s,t): 6 2 6
# Struck Placement Resource (j,s,t): 16 2 6
# Struck Placement Resource (j,s,t): 5 2 7
# Struck Placement Resource (j,s,t): 6 2 7
# Struck Placement Resource (j,s,t): 18 3 7
# Struck Placement Resource (j,s,t): 6 4 8
# Struck Placement Resource (j,s,t): 18 3 8
# Struck Placement Resource (j,s,t): 18 3 9
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 1
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 16 4 4
# Struck Placement Resource (j,s,t): 16 4 5
# Struck Placement Resource (j,s,t): 17 4 3
# Struck Placement Resource (j,s,t): 17 4 4
# Struck Placement Resource (j,s,t): 17 4 2
# not enough resources, simulation broken
# batch_broken, repeating with new users
# batch_prob...
# Struck Placement Resource (j,s,t): 0 4 2
# Struck Placement Resource (j,s,t): 10 4 2
# Struck Placement Resource (j,s,t): 10 4 3
# Struck Placement Resource (j,s,t): 5 4 3
# Struck Placement Resource (j,s,t): 14 1 6
# Struck Placement Resource (j,s,t): 18 1 6
# Struck Placement Resource (j,s,t): 18 1 7
# Struck Placement Resource (j,s,t): 18 1 5
# not enough resources, simulation broken
# batch_broken, repeating with new users
# batch_prob...
# Struck Placement Resource (j,s,t): 15 4 2
# Struck Placement Resource (j,s,t): 15 4 3
# Struck Placement Resource (j,s,t): 15 4 4
# Struck Placement Resource (j,s,t): 4 6 4
# Struck Placement Resource (j,s,t): 2 6 4
# Struck Placement Resource (j,s,t): 2 6 5
# Struck Placement Resource (j,s,t): 16 6 4
# Struck Placement Resource (j,s,t): 16 6 5
# Struck Placement Resource (j,s,t): 7 6 5
# Struck Placement Resource (j,s,t): 7 6 6
# Struck Placement Resource (j,s,t): 9 6 6
# Struck Placement Resource (j,s,t): 9 6 7
# Struck Placement Resource (j,s,t): 12 6 6
# Struck Placement Resource (j,s,t): 12 6 7
# Struck Placement Resource (j,s,t): 2 6 7
# Struck Placement Resource (j,s,t): 2 6 8
# done!
# SG prob...
# Struck Placement Resource (j,s,t): 15 4 2
# Struck Placement Resource (j,s,t): 15 4 3
# Struck Placement Resource (j,s,t): 15 4 4
# Struck Placement Resource (j,s,t): 4 6 4
# Struck Placement Resource (j,s,t): 4 6 5
# Struck Placement Resource (j,s,t): 4 6 6
# Struck Placement Resource (j,s,t): 4 6 7
# Struck Placement Resource (j,s,t): 4 6 8
# Struck Placement Resource (j,s,t): 2 6 4
# Struck Placement Resource (j,s,t): 2 6 5
# Struck Placement Resource (j,s,t): 2 6 6
# Struck Placement Resource (j,s,t): 2 6 7
# Struck Placement Resource (j,s,t): 16 6 4
# Struck Placement Resource (j,s,t): 16 6 5
# Struck Placement Resource (j,s,t): 16 6 6
# Struck Placement Resource (j,s,t): 16 6 7
# Struck Placement Resource (j,s,t): 7 6 5
# Struck Placement Resource (j,s,t): 7 6 6
# Struck Placement Resource (j,s,t): 7 6 7
# Struck Placement Resource (j,s,t): 7 6 8
# Struck Placement Resource (j,s,t): 7 6 9
# done!
# Cloud prob...
# Struck Placement Resource (j,s,t): 15 4 2
# Struck Placement Resource (j,s,t): 15 4 3
# ban_node: 14
# ban_node: 25
# ban_node: 15
# ban_node: 26
# ban_node: 16
# ban_node: 27
# ban_node: 17
# ban_node: 28
# ban_node: 18
# ban_node: 29
# ban_node: 19
# ban_node: 30
# ban_node: 20
# ban_node: 31
# ban_node: 21
# ban_node: 32
# ban_node: 22
# ban_node: 33
# Struck Placement Resource (j,s,t): 15 4 4
# ban_node: 36
# ban_node: 37
# ban_node: 38
# ban_node: 39
# ban_node: 40
# ban_node: 41
# ban_node: 42
# ban_node: 43
# ban_node: 44
# Struck Placement Resource (j,s,t): 16 6 4
# Struck Placement Resource (j,s,t): 16 6 5
# Struck Placement Resource (j,s,t): 16 6 6
# Struck Placement Resource (j,s,t): 16 6 7
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 39
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 40
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 41
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 42
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 43
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 44
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 45
# ban_node: 13
# ban_node: 24
# ban_node: 35
# ban_node: 46
# ban_node: 14
# ban_node: 25
# ban_node: 36
# ban_node: 47
# Struck Placement Resource (j,s,t): 16 6 8
# ban_node: 50
# ban_node: 51
# ban_node: 52
# ban_node: 53
# ban_node: 54
# ban_node: 55
# ban_node: 56
# ban_node: 57
# ban_node: 58
# done!
# Naive prob...
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 15 4 3
# Struck Placement Resource (j,s,t): 15 4 4
# Struck Placement Resource (j,s,t): 16 4 4
# Struck Placement Resource (j,s,t): 1 4 7
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 2
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 8 0 3
# Struck Placement Resource (j,s,t): 8 0 2
# not enough resources, simulation broken
# batch_broken, repeating with new users
# batch_prob...
# Struck Placement Resource (j,s,t): 2 4 7
# done!
# SG prob...
# Struck Placement Resource (j,s,t): 0 6 5
# Struck Placement Resource (j,s,t): 0 6 6
# Struck Placement Resource (j,s,t): 14 6 6
# Struck Placement Resource (j,s,t): 14 6 7
# done!
# Cloud prob...
# Struck Placement Resource (j,s,t): 0 6 5
# Struck Placement Resource (j,s,t): 0 6 6
# ban_node: 17
# ban_node: 28
# ban_node: 18
# ban_node: 29
# ban_node: 19
# ban_node: 30
# ban_node: 20
# ban_node: 31
# ban_node: 21
# ban_node: 32
# ban_node: 22
# ban_node: 33
# ban_node: 23
# ban_node: 34
# ban_node: 24
# ban_node: 35
# ban_node: 25
# ban_node: 36
# Struck Placement Resource (j,s,t): 0 6 7
# ban_node: 39
# ban_node: 40
# ban_node: 41
# ban_node: 42
# ban_node: 43
# ban_node: 44
# ban_node: 45
# ban_node: 46
# ban_node: 47
# Struck Placement Resource (j,s,t): 14 6 6
# Struck Placement Resource (j,s,t): 14 6 7
# ban_node: 28
# ban_node: 39
# ban_node: 29
# ban_node: 40
# ban_node: 30
# ban_node: 41
# ban_node: 31
# ban_node: 42
# ban_node: 32
# ban_node: 43
# ban_node: 33
# ban_node: 44
# ban_node: 34
# ban_node: 45
# ban_node: 35
# ban_node: 46
# ban_node: 36
# ban_node: 47
# Struck Placement Resource (j,s,t): 14 6 8
# ban_node: 50
# ban_node: 51
# ban_node: 52
# ban_node: 53
# ban_node: 54
# ban_node: 55
# ban_node: 56
# ban_node: 57
# ban_node: 58
# done!
# Naive prob...
# Struck Placement Resource (j,s,t): 2 4 2
# Struck Placement Resource (j,s,t): 2 4 3
# Struck Placement Resource (j,s,t): 2 4 4
# Struck Placement Resource (j,s,t): 2 4 5
# Struck Placement Resource (j,s,t): 2 4 6
# Struck Placement Resource (j,s,t): 2 4 7
# Struck Placement Resource (j,s,t): 0 0 4
# Struck Placement Resource (j,s,t): 0 0 5
# Struck Placement Resource (j,s,t): 0 0 6
# Struck Placement Resource (j,s,t): 0 0 7
# Struck Placement Resource (j,s,t): 0 0 8
# Struck Placement Resource (j,s,t): 14 0 4
# Struck Placement Resource (j,s,t): 14 0 5
# Struck Placement Resource (j,s,t): 14 0 6
# Struck Placement Resource (j,s,t): 14 0 7
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 2 4 2
# Struck Placement Resource (j,s,t): 0 0 6
# Struck Placement Resource (j,s,t): 2 1 6
# Struck Placement Resource (j,s,t): 13 0 6
# Struck Placement Resource (j,s,t): 2 4 7
# Struck Placement Resource (j,s,t): 2 4 8
# Struck Placement Resource (j,s,t): 13 4 8
# Struck Placement Resource (j,s,t): 0 1 9
# Struck Placement Resource (j,s,t): 14 4 10
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 3
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 15 2 5
# Struck Placement Resource (j,s,t): 18 3 4
# Struck Placement Resource (j,s,t): 18 3 5
# Struck Placement Resource (j,s,t): 1 3 6
# Struck Placement Resource (j,s,t): 13 2 6
# Struck Placement Resource (j,s,t): 13 2 5
# Struck Placement Resource (j,s,t): 13 2 7
# Struck Placement Resource (j,s,t): 16 5 6
# Struck Placement Resource (j,s,t): 16 5 5
# Struck Placement Resource (j,s,t): 16 5 7
# Struck Placement Resource (j,s,t): 2 2 7
# done!
# SG prob...
# Struck Placement Resource (j,s,t): 18 3 4
# Struck Placement Resource (j,s,t): 18 3 5
# Struck Placement Resource (j,s,t): 18 3 6
# Struck Placement Resource (j,s,t): 16 5 6
# Struck Placement Resource (j,s,t): 16 5 5
# Struck Placement Resource (j,s,t): 16 5 7
# done!
# Cloud prob...
# Struck Placement Resource (j,s,t): 18 3 4
# Struck Placement Resource (j,s,t): 18 3 5
# Struck Placement Resource (j,s,t): 18 3 6
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 13
# ban_node: 24
# ban_node: 35
# ban_node: 14
# ban_node: 25
# ban_node: 36
# Struck Placement Resource (j,s,t): 16 5 6
# ban_node: 18
# ban_node: 19
# ban_node: 20
# ban_node: 21
# ban_node: 22
# ban_node: 23
# ban_node: 24
# ban_node: 25
# ban_node: 26
# Struck Placement Resource (j,s,t): 16 5 7
# ban_node: 29
# ban_node: 30
# ban_node: 31
# ban_node: 32
# ban_node: 33
# ban_node: 34
# ban_node: 35
# ban_node: 36
# ban_node: 37
# done!
# Naive prob...
# Struck Placement Resource (j,s,t): 9 0 0
# Struck Placement Resource (j,s,t): 9 0 1
# Struck Placement Resource (j,s,t): 9 0 2
# Struck Placement Resource (j,s,t): 9 0 3
# Struck Placement Resource (j,s,t): 9 0 4
# Struck Placement Resource (j,s,t): 9 0 5
# Struck Placement Resource (j,s,t): 9 0 6
# Struck Placement Resource (j,s,t): 17 0 0
# Struck Placement Resource (j,s,t): 17 0 1
# Struck Placement Resource (j,s,t): 17 0 2
# Struck Placement Resource (j,s,t): 17 0 3
# Struck Placement Resource (j,s,t): 17 0 4
# Struck Placement Resource (j,s,t): 17 0 5
# Struck Placement Resource (j,s,t): 17 0 6
# Struck Placement Resource (j,s,t): 17 0 7
# Struck Placement Resource (j,s,t): 11 2 2
# Struck Placement Resource (j,s,t): 11 2 3
# Struck Placement Resource (j,s,t): 11 2 4
# Struck Placement Resource (j,s,t): 11 2 5
# Struck Placement Resource (j,s,t): 11 2 6
# Struck Placement Resource (j,s,t): 11 2 7
# Struck Placement Resource (j,s,t): 11 2 8
# Struck Placement Resource (j,s,t): 3 3 3
# Struck Placement Resource (j,s,t): 3 3 4
# Struck Placement Resource (j,s,t): 3 3 5
# Struck Placement Resource (j,s,t): 3 3 6
# Struck Placement Resource (j,s,t): 3 3 7
# Struck Placement Resource (j,s,t): 5 0 3
# Struck Placement Resource (j,s,t): 5 0 4
# Struck Placement Resource (j,s,t): 5 0 5
# Struck Placement Resource (j,s,t): 5 0 6
# Struck Placement Resource (j,s,t): 5 0 7
# Struck Placement Resource (j,s,t): 5 0 8
# Struck Placement Resource (j,s,t): 5 0 9
# Struck Placement Resource (j,s,t): 12 3 3
# Struck Placement Resource (j,s,t): 12 3 4
# Struck Placement Resource (j,s,t): 12 3 5
# Struck Placement Resource (j,s,t): 12 3 6
# Struck Placement Resource (j,s,t): 12 3 7
# Struck Placement Resource (j,s,t): 18 2 4
# Struck Placement Resource (j,s,t): 18 2 5
# Struck Placement Resource (j,s,t): 18 2 6
# Struck Placement Resource (j,s,t): 18 2 7
# Struck Placement Resource (j,s,t): 18 2 8
# Struck Placement Resource (j,s,t): 4 0 5
# Struck Placement Resource (j,s,t): 4 0 6
# Struck Placement Resource (j,s,t): 4 0 7
# Struck Placement Resource (j,s,t): 4 0 8
# Struck Placement Resource (j,s,t): 4 0 9
# Struck Placement Resource (j,s,t): 16 0 5
# Struck Placement Resource (j,s,t): 16 0 6
# Struck Placement Resource (j,s,t): 16 0 7
# Struck Placement Resource (j,s,t): 16 0 8
# Struck Placement Resource (j,s,t): 16 0 9
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 9 0 0
# Struck Placement Resource (j,s,t): 9 0 1
# Struck Placement Resource (j,s,t): 17 0 0
# Struck Placement Resource (j,s,t): 17 0 1
# Struck Placement Resource (j,s,t): 9 0 2
# Struck Placement Resource (j,s,t): 10 2 1
# Struck Placement Resource (j,s,t): 10 2 2
# Struck Placement Resource (j,s,t): 17 0 2
# Struck Placement Resource (j,s,t): 10 2 3
# Struck Placement Resource (j,s,t): 11 2 2
# Struck Placement Resource (j,s,t): 11 2 3
# Struck Placement Resource (j,s,t): 10 2 4
# Struck Placement Resource (j,s,t): 11 2 4
# Struck Placement Resource (j,s,t): 1 3 5
# Struck Placement Resource (j,s,t): 2 2 5
# Struck Placement Resource (j,s,t): 10 2 5
# Struck Placement Resource (j,s,t): 11 2 5
# Struck Placement Resource (j,s,t): 18 2 4
# Struck Placement Resource (j,s,t): 18 3 5
# Struck Placement Resource (j,s,t): 1 3 6
# Struck Placement Resource (j,s,t): 2 2 6
# Struck Placement Resource (j,s,t): 5 3 6
# Struck Placement Resource (j,s,t): 10 2 6
# Struck Placement Resource (j,s,t): 11 2 6
# Struck Placement Resource (j,s,t): 15 2 6
# Struck Placement Resource (j,s,t): 18 2 6
# Struck Placement Resource (j,s,t): 1 3 7
# Struck Placement Resource (j,s,t): 2 2 7
# Struck Placement Resource (j,s,t): 10 2 7
# Struck Placement Resource (j,s,t): 11 2 7
# Struck Placement Resource (j,s,t): 18 2 7
# Struck Placement Resource (j,s,t): 1 3 8
# Struck Placement Resource (j,s,t): 2 2 8
# Struck Placement Resource (j,s,t): 11 5 8
# Struck Placement Resource (j,s,t): 18 2 8
# Struck Placement Resource (j,s,t): 2 2 9
# Struck Placement Resource (j,s,t): 18 2 9
# Struck Placement Resource (j,s,t): 2 3 10
# Struck Placement Resource (j,s,t): 18 5 10
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 4
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 17 7 5
# Struck Placement Resource (j,s,t): 5 2 6
# done!
# SG prob...
# Struck Placement Resource (j,s,t): 14 7 3
# Struck Placement Resource (j,s,t): 14 7 4
# Struck Placement Resource (j,s,t): 14 7 5
# Struck Placement Resource (j,s,t): 14 7 6
# done!
# Cloud prob...
# Struck Placement Resource (j,s,t): 14 7 3
# Struck Placement Resource (j,s,t): 14 7 4
# Struck Placement Resource (j,s,t): 14 7 5
# ban_node: 5
# ban_node: 16
# ban_node: 27
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 13
# ban_node: 24
# ban_node: 35
# Struck Placement Resource (j,s,t): 14 7 6
# ban_node: 38
# ban_node: 39
# ban_node: 40
# ban_node: 41
# ban_node: 42
# ban_node: 43
# ban_node: 44
# ban_node: 45
# ban_node: 46
# done!
# Naive prob...
# Struck Placement Resource (j,s,t): 3 3 3
# Struck Placement Resource (j,s,t): 3 3 4
# Struck Placement Resource (j,s,t): 3 3 5
# Struck Placement Resource (j,s,t): 3 3 6
# Struck Placement Resource (j,s,t): 3 3 7
# Struck Placement Resource (j,s,t): 3 3 8
# Struck Placement Resource (j,s,t): 3 3 9
# Struck Placement Resource (j,s,t): 14 3 3
# Struck Placement Resource (j,s,t): 14 3 4
# Struck Placement Resource (j,s,t): 14 3 5
# Struck Placement Resource (j,s,t): 14 3 6
# Struck Placement Resource (j,s,t): 14 3 7
# Struck Placement Resource (j,s,t): 14 3 8
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 16 5 3
# Struck Placement Resource (j,s,t): 16 5 4
# Struck Placement Resource (j,s,t): 5 2 5
# Struck Placement Resource (j,s,t): 17 5 5
# Struck Placement Resource (j,s,t): 17 7 5
# Struck Placement Resource (j,s,t): 5 2 6
# Struck Placement Resource (j,s,t): 5 3 7
# Struck Placement Resource (j,s,t): 5 3 8
# Struck Placement Resource (j,s,t): 5 3 9
# Struck Placement Resource (j,s,t): 15 5 9
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 5
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 15 1 2
# Struck Placement Resource (j,s,t): 15 1 3
# Struck Placement Resource (j,s,t): 15 1 4
# Struck Placement Resource (j,s,t): 13 3 5
# Struck Placement Resource (j,s,t): 18 3 5
# Struck Placement Resource (j,s,t): 18 3 4
# not enough resources, simulation broken
# batch_broken, repeating with new users
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 17 2 5
# Struck Placement Resource (j,s,t): 13 4 6
# Struck Placement Resource (j,s,t): 13 4 7
# Struck Placement Resource (j,s,t): 5 2 8
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 6
# limited
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# Struck Placement Resource (j,s,t): 16 1 2
# Struck Placement Resource (j,s,t): 16 1 3
# Struck Placement Resource (j,s,t): 16 1 4
# Struck Placement Resource (j,s,t): 16 1 5
# Struck Placement Resource (j,s,t): 16 1 6
# Struck Placement Resource (j,s,t): 16 1 7
# Struck Placement Resource (j,s,t): 18 2 6
# Struck Placement Resource (j,s,t): 18 2 7
# Struck Placement Resource (j,s,t): 18 2 8
# Struck Placement Resource (j,s,t): 18 2 9
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 1 3 2
# Struck Placement Resource (j,s,t): 10 0 3
# Struck Placement Resource (j,s,t): 17 2 3
# Struck Placement Resource (j,s,t): 17 2 4
# Struck Placement Resource (j,s,t): 13 0 5
# Struck Placement Resource (j,s,t): 17 2 5
# Struck Placement Resource (j,s,t): 13 0 6
# Struck Placement Resource (j,s,t): 16 3 9
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 7
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 14 8 3
# Struck Placement Resource (j,s,t): 14 8 4
# Struck Placement Resource (j,s,t): 14 1 3
# Struck Placement Resource (j,s,t): 14 8 5
# Struck Placement Resource (j,s,t): 18 8 3
# Struck Placement Resource (j,s,t): 18 8 4
# Struck Placement Resource (j,s,t): 18 1 3
# Struck Placement Resource (j,s,t): 18 8 5
# Struck Placement Resource (j,s,t): 18 0 3
# Struck Placement Resource (j,s,t): 18 0 4
# Struck Placement Resource (j,s,t): 18 1 4
# Struck Placement Resource (j,s,t): 10 8 5
# Struck Placement Resource (j,s,t): 0 0 5
# Struck Placement Resource (j,s,t): 0 8 5
# Struck Placement Resource (j,s,t): 0 0 6
# Struck Placement Resource (j,s,t): 0 8 6
# Struck Placement Resource (j,s,t): 14 1 6
# Struck Placement Resource (j,s,t): 14 8 6
# Struck Placement Resource (j,s,t): 14 0 6
# Struck Placement Resource (j,s,t): 14 8 7
# Struck Placement Resource (j,s,t): 14 0 5
# not enough resources, simulation broken
# batch_broken, repeating with new users
# batch_prob...
# Struck Placement Resource (j,s,t): 6 1 1
# Struck Placement Resource (j,s,t): 6 1 2
# Struck Placement Resource (j,s,t): 6 1 3
# Struck Placement Resource (j,s,t): 19 1 1
# Struck Placement Resource (j,s,t): 19 1 2
# Struck Placement Resource (j,s,t): 19 1 3
# Struck Placement Resource (j,s,t): 12 1 2
# Struck Placement Resource (j,s,t): 12 1 3
# Struck Placement Resource (j,s,t): 12 1 4
# Struck Placement Resource (j,s,t): 14 1 2
# Struck Placement Resource (j,s,t): 14 1 3
# Struck Placement Resource (j,s,t): 14 1 4
# Struck Placement Resource (j,s,t): 16 1 2
# Struck Placement Resource (j,s,t): 16 1 3
# Struck Placement Resource (j,s,t): 16 1 4
# Struck Placement Resource (j,s,t): 6 1 4
# Struck Placement Resource (j,s,t): 6 1 5
# Struck Placement Resource (j,s,t): 7 1 4
# Struck Placement Resource (j,s,t): 7 1 5
# Struck Placement Resource (j,s,t): 11 1 3
# Struck Placement Resource (j,s,t): 11 1 4
# Struck Placement Resource (j,s,t): 11 1 5
# Struck Placement Resource (j,s,t): 15 1 3
# Struck Placement Resource (j,s,t): 15 1 4
# Struck Placement Resource (j,s,t): 6 1 6
# Struck Placement Resource (j,s,t): 7 1 6
# Struck Placement Resource (j,s,t): 7 1 7
# Struck Placement Resource (j,s,t): 9 1 6
# Struck Placement Resource (j,s,t): 9 1 7
# Struck Placement Resource (j,s,t): 9 1 8
# Struck Placement Resource (j,s,t): 12 1 7
# Struck Placement Resource (j,s,t): 12 1 8
# Struck Placement Resource (j,s,t): 18 1 7
# Struck Placement Resource (j,s,t): 7 1 8
# Struck Placement Resource (j,s,t): 7 1 9
# Struck Placement Resource (j,s,t): 10 1 8
# Struck Placement Resource (j,s,t): 15 1 8
# Struck Placement Resource (j,s,t): 17 8 8
# Struck Placement Resource (j,s,t): 17 1 8
# done!
# SG prob...
# Struck Placement Resource (j,s,t): 6 1 1
# Struck Placement Resource (j,s,t): 6 1 2
# Struck Placement Resource (j,s,t): 6 1 3
# Struck Placement Resource (j,s,t): 6 1 4
# Struck Placement Resource (j,s,t): 19 1 1
# Struck Placement Resource (j,s,t): 19 1 2
# Struck Placement Resource (j,s,t): 12 1 2
# Struck Placement Resource (j,s,t): 12 1 3
# Struck Placement Resource (j,s,t): 14 1 2
# Struck Placement Resource (j,s,t): 14 1 3
# Struck Placement Resource (j,s,t): 16 1 2
# Struck Placement Resource (j,s,t): 16 1 3
# Struck Placement Resource (j,s,t): 16 1 4
# Struck Placement Resource (j,s,t): 10 8 5
# Struck Placement Resource (j,s,t): 11 1 3
# Struck Placement Resource (j,s,t): 11 1 4
# Struck Placement Resource (j,s,t): 11 1 5
# Struck Placement Resource (j,s,t): 11 8 3
# Struck Placement Resource (j,s,t): 11 8 4
# Struck Placement Resource (j,s,t): 11 8 5
# Struck Placement Resource (j,s,t): 15 1 3
# Struck Placement Resource (j,s,t): 15 1 4
# Struck Placement Resource (j,s,t): 15 1 5
# Struck Placement Resource (j,s,t): 15 1 6
# Struck Placement Resource (j,s,t): 15 1 7
# Struck Placement Resource (j,s,t): 15 8 3
# Struck Placement Resource (j,s,t): 15 8 4
# Struck Placement Resource (j,s,t): 15 1 8
# Struck Placement Resource (j,s,t): 15 8 5
# Struck Placement Resource (j,s,t): 9 1 6
# Struck Placement Resource (j,s,t): 9 1 7
# Struck Placement Resource (j,s,t): 9 1 8
# Struck Placement Resource (j,s,t): 9 1 9
# done!
# Cloud prob...
# Struck Placement Resource (j,s,t): 6 1 1
# Struck Placement Resource (j,s,t): 6 1 2
# Struck Placement Resource (j,s,t): 6 1 3
# ban_node: 3
# ban_node: 14
# ban_node: 25
# ban_node: 4
# ban_node: 15
# ban_node: 26
# ban_node: 5
# ban_node: 16
# ban_node: 27
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 11
# ban_node: 22
# ban_node: 33
# Struck Placement Resource (j,s,t): 6 1 4
# ban_node: 36
# ban_node: 37
# ban_node: 38
# ban_node: 39
# ban_node: 40
# ban_node: 41
# ban_node: 42
# ban_node: 43
# ban_node: 44
# Struck Placement Resource (j,s,t): 19 1 1
# Struck Placement Resource (j,s,t): 19 1 2
# ban_node: 3
# ban_node: 14
# ban_node: 4
# ban_node: 15
# ban_node: 5
# ban_node: 16
# ban_node: 6
# ban_node: 17
# ban_node: 7
# ban_node: 18
# ban_node: 8
# ban_node: 19
# ban_node: 9
# ban_node: 20
# ban_node: 10
# ban_node: 21
# ban_node: 11
# ban_node: 22
# Struck Placement Resource (j,s,t): 12 1 2
# Struck Placement Resource (j,s,t): 12 1 3
# ban_node: 4
# ban_node: 15
# ban_node: 5
# ban_node: 16
# ban_node: 6
# ban_node: 17
# ban_node: 7
# ban_node: 18
# ban_node: 8
# ban_node: 19
# ban_node: 9
# ban_node: 20
# ban_node: 10
# ban_node: 21
# ban_node: 11
# ban_node: 22
# ban_node: 12
# ban_node: 23
# Struck Placement Resource (j,s,t): 14 1 2
# Struck Placement Resource (j,s,t): 14 1 3
# ban_node: 4
# ban_node: 15
# ban_node: 5
# ban_node: 16
# ban_node: 6
# ban_node: 17
# ban_node: 7
# ban_node: 18
# ban_node: 8
# ban_node: 19
# ban_node: 9
# ban_node: 20
# ban_node: 10
# ban_node: 21
# ban_node: 11
# ban_node: 22
# ban_node: 12
# ban_node: 23
# Struck Placement Resource (j,s,t): 16 1 2
# Struck Placement Resource (j,s,t): 16 1 3
# Struck Placement Resource (j,s,t): 16 1 4
# ban_node: 4
# ban_node: 15
# ban_node: 26
# ban_node: 5
# ban_node: 16
# ban_node: 27
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 12
# ban_node: 23
# ban_node: 34
# Struck Placement Resource (j,s,t): 11 1 3
# Struck Placement Resource (j,s,t): 11 1 4
# Struck Placement Resource (j,s,t): 11 1 5
# ban_node: 5
# ban_node: 16
# ban_node: 27
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 13
# ban_node: 24
# ban_node: 35
# Struck Placement Resource (j,s,t): 15 1 3
# Struck Placement Resource (j,s,t): 15 1 4
# Struck Placement Resource (j,s,t): 15 1 5
# Struck Placement Resource (j,s,t): 15 1 6
# Struck Placement Resource (j,s,t): 15 1 7
# ban_node: 5
# ban_node: 16
# ban_node: 27
# ban_node: 38
# ban_node: 49
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 39
# ban_node: 50
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 40
# ban_node: 51
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 41
# ban_node: 52
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 42
# ban_node: 53
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 43
# ban_node: 54
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 44
# ban_node: 55
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 45
# ban_node: 56
# ban_node: 13
# ban_node: 24
# ban_node: 35
# ban_node: 46
# ban_node: 57
# Struck Placement Resource (j,s,t): 15 1 8
# ban_node: 60
# ban_node: 61
# ban_node: 62
# ban_node: 63
# ban_node: 64
# ban_node: 65
# ban_node: 66
# ban_node: 67
# ban_node: 68
# Struck Placement Resource (j,s,t): 9 1 6
# Struck Placement Resource (j,s,t): 9 1 7
# Struck Placement Resource (j,s,t): 9 1 8
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 13
# ban_node: 24
# ban_node: 35
# ban_node: 14
# ban_node: 25
# ban_node: 36
# ban_node: 15
# ban_node: 26
# ban_node: 37
# ban_node: 16
# ban_node: 27
# ban_node: 38
# Struck Placement Resource (j,s,t): 9 1 9
# ban_node: 41
# ban_node: 42
# ban_node: 43
# ban_node: 44
# ban_node: 45
# ban_node: 46
# ban_node: 47
# ban_node: 48
# ban_node: 49
# done!
# Naive prob...
# Struck Placement Resource (j,s,t): 6 1 1
# Struck Placement Resource (j,s,t): 6 1 2
# Struck Placement Resource (j,s,t): 6 1 3
# Struck Placement Resource (j,s,t): 6 1 4
# Struck Placement Resource (j,s,t): 6 1 5
# Struck Placement Resource (j,s,t): 6 1 6
# Struck Placement Resource (j,s,t): 16 1 2
# Struck Placement Resource (j,s,t): 16 1 3
# Struck Placement Resource (j,s,t): 16 1 4
# Struck Placement Resource (j,s,t): 16 1 5
# Struck Placement Resource (j,s,t): 16 1 6
# Struck Placement Resource (j,s,t): 16 1 7
# Struck Placement Resource (j,s,t): 16 1 8
# Struck Placement Resource (j,s,t): 18 1 2
# Struck Placement Resource (j,s,t): 18 1 3
# Struck Placement Resource (j,s,t): 18 1 4
# Struck Placement Resource (j,s,t): 18 1 5
# Struck Placement Resource (j,s,t): 18 1 6
# Struck Placement Resource (j,s,t): 18 1 7
# Struck Placement Resource (j,s,t): 11 1 3
# Struck Placement Resource (j,s,t): 11 1 4
# Struck Placement Resource (j,s,t): 11 1 5
# Struck Placement Resource (j,s,t): 11 1 6
# Struck Placement Resource (j,s,t): 11 1 7
# Struck Placement Resource (j,s,t): 15 1 3
# Struck Placement Resource (j,s,t): 15 1 4
# Struck Placement Resource (j,s,t): 15 1 5
# Struck Placement Resource (j,s,t): 15 1 6
# Struck Placement Resource (j,s,t): 15 1 7
# Struck Placement Resource (j,s,t): 4 1 6
# Struck Placement Resource (j,s,t): 4 1 7
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 6 1 1
# Struck Placement Resource (j,s,t): 6 1 2
# Struck Placement Resource (j,s,t): 19 1 2
# Struck Placement Resource (j,s,t): 6 1 3
# Struck Placement Resource (j,s,t): 12 1 2
# Struck Placement Resource (j,s,t): 12 1 3
# Struck Placement Resource (j,s,t): 14 1 3
# Struck Placement Resource (j,s,t): 16 1 2
# Struck Placement Resource (j,s,t): 16 1 3
# Struck Placement Resource (j,s,t): 18 1 2
# Struck Placement Resource (j,s,t): 6 1 4
# Struck Placement Resource (j,s,t): 7 1 4
# Struck Placement Resource (j,s,t): 11 1 3
# Struck Placement Resource (j,s,t): 11 1 4
# Struck Placement Resource (j,s,t): 12 1 4
# Struck Placement Resource (j,s,t): 15 1 3
# Struck Placement Resource (j,s,t): 15 1 4
# Struck Placement Resource (j,s,t): 16 1 4
# Struck Placement Resource (j,s,t): 18 1 4
# Struck Placement Resource (j,s,t): 6 1 5
# Struck Placement Resource (j,s,t): 10 1 5
# Struck Placement Resource (j,s,t): 11 1 5
# Struck Placement Resource (j,s,t): 12 1 5
# Struck Placement Resource (j,s,t): 16 1 5
# Struck Placement Resource (j,s,t): 6 1 6
# Struck Placement Resource (j,s,t): 7 1 6
# Struck Placement Resource (j,s,t): 10 1 6
# Struck Placement Resource (j,s,t): 11 1 6
# Struck Placement Resource (j,s,t): 12 1 6
# Struck Placement Resource (j,s,t): 18 1 6
# Struck Placement Resource (j,s,t): 19 1 6
# Struck Placement Resource (j,s,t): 19 8 6
# Struck Placement Resource (j,s,t): 7 1 7
# Struck Placement Resource (j,s,t): 10 1 7
# Struck Placement Resource (j,s,t): 12 1 7
# Struck Placement Resource (j,s,t): 15 1 7
# Struck Placement Resource (j,s,t): 18 1 7
# Struck Placement Resource (j,s,t): 19 1 7
# Struck Placement Resource (j,s,t): 7 1 8
# Struck Placement Resource (j,s,t): 10 1 8
# Struck Placement Resource (j,s,t): 12 1 8
# Struck Placement Resource (j,s,t): 15 1 8
# Struck Placement Resource (j,s,t): 19 1 8
# Struck Placement Resource (j,s,t): 7 1 9
# Struck Placement Resource (j,s,t): 12 1 9
# Struck Placement Resource (j,s,t): 19 1 9
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 8
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 18 1 2
# Struck Placement Resource (j,s,t): 18 1 3
# Struck Placement Resource (j,s,t): 18 1 4
# Struck Placement Resource (j,s,t): 5 1 6
# Struck Placement Resource (j,s,t): 7 2 8
# Struck Placement Resource (j,s,t): 7 2 9
# Struck Placement Resource (j,s,t): 14 1 8
# Struck Placement Resource (j,s,t): 14 1 9
# Struck Placement Resource (j,s,t): 5 1 9
# done!
# SG prob...
# Struck Placement Resource (j,s,t): 18 1 2
# Struck Placement Resource (j,s,t): 18 1 3
# Struck Placement Resource (j,s,t): 1 6 4
# Struck Placement Resource (j,s,t): 1 6 5
# Struck Placement Resource (j,s,t): 1 6 6
# Struck Placement Resource (j,s,t): 1 6 7
# Struck Placement Resource (j,s,t): 16 6 3
# Struck Placement Resource (j,s,t): 16 6 4
# Struck Placement Resource (j,s,t): 10 6 7
# Struck Placement Resource (j,s,t): 10 6 8
# Struck Placement Resource (j,s,t): 11 6 7
# Struck Placement Resource (j,s,t): 11 6 8
# Struck Placement Resource (j,s,t): 11 6 6
# Struck Placement Resource (j,s,t): 11 6 9
# Struck Placement Resource (j,s,t): 5 1 6
# done!
# Cloud prob...
# Struck Placement Resource (j,s,t): 18 1 2
# ban_node: 4
# ban_node: 5
# ban_node: 6
# ban_node: 7
# ban_node: 8
# ban_node: 9
# ban_node: 10
# ban_node: 11
# ban_node: 12
# Struck Placement Resource (j,s,t): 18 1 3
# ban_node: 15
# ban_node: 16
# ban_node: 17
# ban_node: 18
# ban_node: 19
# ban_node: 20
# ban_node: 21
# ban_node: 22
# ban_node: 23
# Struck Placement Resource (j,s,t): 1 6 4
# Struck Placement Resource (j,s,t): 1 6 5
# Struck Placement Resource (j,s,t): 1 6 6
# ban_node: 16
# ban_node: 27
# ban_node: 38
# ban_node: 17
# ban_node: 28
# ban_node: 39
# ban_node: 18
# ban_node: 29
# ban_node: 40
# ban_node: 19
# ban_node: 30
# ban_node: 41
# ban_node: 20
# ban_node: 31
# ban_node: 42
# ban_node: 21
# ban_node: 32
# ban_node: 43
# ban_node: 22
# ban_node: 33
# ban_node: 44
# ban_node: 23
# ban_node: 34
# ban_node: 45
# ban_node: 24
# ban_node: 35
# ban_node: 46
# Struck Placement Resource (j,s,t): 1 6 7
# ban_node: 49
# ban_node: 50
# ban_node: 51
# ban_node: 52
# ban_node: 53
# ban_node: 54
# ban_node: 55
# ban_node: 56
# ban_node: 57
# Struck Placement Resource (j,s,t): 16 6 3
# Struck Placement Resource (j,s,t): 16 6 4
# ban_node: 5
# ban_node: 16
# ban_node: 6
# ban_node: 17
# ban_node: 7
# ban_node: 18
# ban_node: 8
# ban_node: 19
# ban_node: 9
# ban_node: 20
# ban_node: 10
# ban_node: 21
# ban_node: 11
# ban_node: 22
# ban_node: 12
# ban_node: 23
# ban_node: 13
# ban_node: 24
# Struck Placement Resource (j,s,t): 10 6 7
# ban_node: 39
# ban_node: 40
# ban_node: 41
# ban_node: 42
# ban_node: 43
# ban_node: 44
# ban_node: 45
# ban_node: 46
# ban_node: 47
# Struck Placement Resource (j,s,t): 10 6 8
# ban_node: 50
# ban_node: 51
# ban_node: 52
# ban_node: 53
# ban_node: 54
# ban_node: 55
# ban_node: 56
# ban_node: 57
# ban_node: 58
# Struck Placement Resource (j,s,t): 11 6 5
# Struck Placement Resource (j,s,t): 11 6 6
# Struck Placement Resource (j,s,t): 11 6 7
# Struck Placement Resource (j,s,t): 11 6 8
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 40
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 41
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 42
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 43
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 44
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 45
# ban_node: 13
# ban_node: 24
# ban_node: 35
# ban_node: 46
# ban_node: 14
# ban_node: 25
# ban_node: 36
# ban_node: 47
# ban_node: 15
# ban_node: 26
# ban_node: 37
# ban_node: 48
# Struck Placement Resource (j,s,t): 11 6 9
# ban_node: 51
# ban_node: 52
# ban_node: 53
# ban_node: 54
# ban_node: 55
# ban_node: 56
# ban_node: 57
# ban_node: 58
# ban_node: 59
# Struck Placement Resource (j,s,t): 5 1 6
# ban_node: 8
# ban_node: 9
# ban_node: 10
# ban_node: 11
# ban_node: 12
# ban_node: 13
# ban_node: 14
# ban_node: 15
# ban_node: 16
# done!
# Naive prob...
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 18 1 2
# Struck Placement Resource (j,s,t): 18 1 3
# Struck Placement Resource (j,s,t): 16 2 3
# Struck Placement Resource (j,s,t): 18 1 4
# Struck Placement Resource (j,s,t): 18 1 5
# Struck Placement Resource (j,s,t): 16 2 6
# Struck Placement Resource (j,s,t): 5 1 7
# Struck Placement Resource (j,s,t): 6 1 7
# Struck Placement Resource (j,s,t): 14 1 7
# Struck Placement Resource (j,s,t): 16 2 7
# Struck Placement Resource (j,s,t): 5 1 8
# Struck Placement Resource (j,s,t): 6 1 8
# Struck Placement Resource (j,s,t): 10 1 8
# Struck Placement Resource (j,s,t): 14 1 8
# Struck Placement Resource (j,s,t): 16 2 8
# Struck Placement Resource (j,s,t): 5 1 9
# Struck Placement Resource (j,s,t): 14 1 9
# Struck Placement Resource (j,s,t): 16 2 9
# Struck Placement Resource (j,s,t): 10 1 10
# Struck Placement Resource (j,s,t): 14 1 10
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!
# Trial Number: 9
# limited
# batch_prob...
# Struck Placement Resource (j,s,t): 3 5 5
# Struck Placement Resource (j,s,t): 6 2 5
# Struck Placement Resource (j,s,t): 6 2 6
# Struck Placement Resource (j,s,t): 3 5 7
# Struck Placement Resource (j,s,t): 6 5 7
# done!
# SG prob...
# Struck Placement Resource (j,s,t): 16 5 4
# Struck Placement Resource (j,s,t): 16 5 5
# Struck Placement Resource (j,s,t): 16 5 6
# Struck Placement Resource (j,s,t): 16 5 7
# Struck Placement Resource (j,s,t): 16 5 8
# Struck Placement Resource (j,s,t): 16 5 9
# done!
# Cloud prob...
# Struck Placement Resource (j,s,t): 16 5 4
# Struck Placement Resource (j,s,t): 16 5 5
# Struck Placement Resource (j,s,t): 16 5 6
# Struck Placement Resource (j,s,t): 16 5 7
# Struck Placement Resource (j,s,t): 16 5 8
# ban_node: 6
# ban_node: 17
# ban_node: 28
# ban_node: 39
# ban_node: 50
# ban_node: 7
# ban_node: 18
# ban_node: 29
# ban_node: 40
# ban_node: 51
# ban_node: 8
# ban_node: 19
# ban_node: 30
# ban_node: 41
# ban_node: 52
# ban_node: 9
# ban_node: 20
# ban_node: 31
# ban_node: 42
# ban_node: 53
# ban_node: 10
# ban_node: 21
# ban_node: 32
# ban_node: 43
# ban_node: 54
# ban_node: 11
# ban_node: 22
# ban_node: 33
# ban_node: 44
# ban_node: 55
# ban_node: 12
# ban_node: 23
# ban_node: 34
# ban_node: 45
# ban_node: 56
# ban_node: 13
# ban_node: 24
# ban_node: 35
# ban_node: 46
# ban_node: 57
# ban_node: 14
# ban_node: 25
# ban_node: 36
# ban_node: 47
# ban_node: 58
# Struck Placement Resource (j,s,t): 16 5 9
# ban_node: 61
# ban_node: 62
# ban_node: 63
# ban_node: 64
# ban_node: 65
# ban_node: 66
# ban_node: 67
# ban_node: 68
# ban_node: 69
# done!
# Naive prob...
# Struck Placement Resource (j,s,t): 14 0 3
# Struck Placement Resource (j,s,t): 14 0 4
# Struck Placement Resource (j,s,t): 14 0 5
# Struck Placement Resource (j,s,t): 14 0 6
# Struck Placement Resource (j,s,t): 16 5 4
# Struck Placement Resource (j,s,t): 16 5 5
# Struck Placement Resource (j,s,t): 16 5 6
# Struck Placement Resource (j,s,t): 16 5 7
# Struck Placement Resource (j,s,t): 5 5 5
# Struck Placement Resource (j,s,t): 5 5 6
# Struck Placement Resource (j,s,t): 5 5 7
# done!
# Myopic prob...
# Struck Placement Resource (j,s,t): 18 5 4
# Struck Placement Resource (j,s,t): 3 5 5
# Struck Placement Resource (j,s,t): 18 0 5
# Struck Placement Resource (j,s,t): 3 5 6
# Struck Placement Resource (j,s,t): 18 0 6
# Struck Placement Resource (j,s,t): 3 5 7
# Struck Placement Resource (j,s,t): 4 2 7
# Struck Placement Resource (j,s,t): 6 5 7
# Struck Placement Resource (j,s,t): 6 5 8
# Struck Placement Resource (j,s,t): 11 5 8
# Struck Placement Resource (j,s,t): 6 5 9
# Struck Placement Resource (j,s,t): 8 4 9
# Struck Placement Resource (j,s,t): 11 5 9
# Struck Placement Resource (j,s,t): 6 2 10
# done!
# ample
# batch_prob...
# done!
# SG prob...
# done!
# Cloud prob...
# done!
# Naive prob...
# done!
# Myopic prob...
# done!

# %% [markdown]
# ### Obtain and plot cost

# %%
num_trials = len(Batch_cost_stores)

SG_total_sum = np.zeros(num_trials)
SG_placement_sum = np.zeros(num_trials)
SG_bw_sum = np.zeros(num_trials)
SG_UE_sum = np.zeros(num_trials)

Batch_total_sum = np.zeros(num_trials)
Batch_placement_sum = np.zeros(num_trials)
Batch_bw_sum = np.zeros(num_trials)
Batch_UE_sum = np.zeros(num_trials)

Myopic_total_sum = np.zeros(num_trials)
Myopic_placement_sum = np.zeros(num_trials)
Myopic_bw_sum = np.zeros(num_trials)
Myopic_UE_sum = np.zeros(num_trials)

Naive_total_sum = np.zeros(num_trials)
Naive_placement_sum = np.zeros(num_trials)
Naive_bw_sum = np.zeros(num_trials)
Naive_UE_sum = np.zeros(num_trials)

Cloud_total_sum = np.zeros(num_trials)
Cloud_placement_sum = np.zeros(num_trials)
Cloud_bw_sum = np.zeros(num_trials)
Cloud_UE_sum = np.zeros(num_trials)

for i in range(num_trials):

    SG_total_sum[i] += SG_cost_stores[i].all_cost_cumulative["total_cost"][-1]
    SG_placement_sum[i] += SG_cost_stores[i].all_cost_cumulative["placement_cost"][-1]
    SG_bw_sum[i] += SG_cost_stores[i].all_cost_cumulative["srv_bw_cost"][-1]
    SG_bw_sum[i] += SG_cost_stores[i].all_cost_cumulative["mig_bw_cost"][-1]
    SG_UE_sum[i] += SG_cost_stores[i].all_cost_cumulative["thruput_cost"][-1]
    SG_UE_sum[i] += SG_cost_stores[i].all_cost_cumulative["latency_cost"][-1]

    Batch_total_sum[i] += Batch_cost_stores[i].all_cost_cumulative["total_cost"][-1]
    Batch_placement_sum[i] += Batch_cost_stores[i].all_cost_cumulative["placement_cost"][-1]
    Batch_bw_sum[i] += Batch_cost_stores[i].all_cost_cumulative["srv_bw_cost"][-1]
    Batch_bw_sum[i] += Batch_cost_stores[i].all_cost_cumulative["mig_bw_cost"][-1]
    Batch_UE_sum[i] += Batch_cost_stores[i].all_cost_cumulative["thruput_cost"][-1]
    Batch_UE_sum[i] += Batch_cost_stores[i].all_cost_cumulative["latency_cost"][-1]
    
    Myopic_total_sum[i] += Myopic_cost_stores[i].all_cost_cumulative["total_cost"][-1]
    Myopic_placement_sum[i] += Myopic_cost_stores[i].all_cost_cumulative["placement_cost"][-1]
    Myopic_bw_sum[i] += Myopic_cost_stores[i].all_cost_cumulative["srv_bw_cost"][-1]
    Myopic_bw_sum[i] += Myopic_cost_stores[i].all_cost_cumulative["mig_bw_cost"][-1]
    Myopic_UE_sum[i] += Myopic_cost_stores[i].all_cost_cumulative["thruput_cost"][-1]
    Myopic_UE_sum[i] += Myopic_cost_stores[i].all_cost_cumulative["latency_cost"][-1]
    
    Naive_total_sum[i] += Naive_cost_stores[i].all_cost_cumulative["total_cost"][-1]
    Naive_placement_sum[i] += Naive_cost_stores[i].all_cost_cumulative["placement_cost"][-1]
    Naive_bw_sum[i] += Naive_cost_stores[i].all_cost_cumulative["srv_bw_cost"][-1]
    Naive_bw_sum[i] += Naive_cost_stores[i].all_cost_cumulative["mig_bw_cost"][-1]
    Naive_UE_sum[i] += Naive_cost_stores[i].all_cost_cumulative["thruput_cost"][-1]
    Naive_UE_sum[i] += Naive_cost_stores[i].all_cost_cumulative["latency_cost"][-1]
    
    Cloud_total_sum[i] += Cloud_cost_stores[i].all_cost_cumulative["total_cost"][-1]
    Cloud_placement_sum[i] += Cloud_cost_stores[i].all_cost_cumulative["placement_cost"][-1]
    Cloud_bw_sum[i] += Cloud_cost_stores[i].all_cost_cumulative["srv_bw_cost"][-1]
    Cloud_bw_sum[i] += Cloud_cost_stores[i].all_cost_cumulative["mig_bw_cost"][-1]
    Cloud_UE_sum[i] += Cloud_cost_stores[i].all_cost_cumulative["thruput_cost"][-1]
    Cloud_UE_sum[i] += Cloud_cost_stores[i].all_cost_cumulative["latency_cost"][-1]

# %% [markdown]
# Plot total costs for all 4 scenarios sub cost?

# %%
# Plot the plot
import matplotlib
import matplotlib.pyplot as plt

# Set Font Size Limitations
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 17}

matplotlib.rc('font', **font)

# Set Labels
labels = ['Total', 'Placement', 'BW', 'UE']

# Obtain Values to Plot
SG_means = [np.mean(SG_total_sum), np.mean(SG_placement_sum), np.mean(SG_bw_sum), np.mean(SG_UE_sum)]
Batch_means = [np.mean(Batch_total_sum), np.mean(Batch_placement_sum), np.mean(Batch_bw_sum), np.mean(Batch_UE_sum)]
Myopic_means = [np.mean(Myopic_total_sum), np.mean(Myopic_placement_sum), np.mean(Myopic_bw_sum), np.mean(Myopic_UE_sum)]
Naive_means = [np.mean(Naive_total_sum), np.mean(Naive_placement_sum), np.mean(Naive_bw_sum), np.mean(Naive_UE_sum)]
Cloud_means = [np.mean(Cloud_total_sum), np.mean(Cloud_placement_sum), np.mean(Cloud_bw_sum), np.mean(Cloud_UE_sum)]


SG_var = [np.std(SG_total_sum), np.std(SG_placement_sum), np.std(SG_bw_sum), np.std(SG_UE_sum)]
Batch_var = [np.std(Batch_total_sum), np.std(Batch_placement_sum), np.std(Batch_bw_sum), np.std(Batch_UE_sum)]
Myopic_var = [np.std(Myopic_total_sum), np.std(Myopic_placement_sum), np.std(Myopic_bw_sum), np.std(Myopic_UE_sum)]
Naive_var = [np.std(Naive_total_sum), np.std(Naive_placement_sum), np.std(Naive_bw_sum), np.std(Naive_UE_sum)]
Cloud_var = [np.std(Cloud_total_sum), np.std(Cloud_placement_sum), np.std(Cloud_bw_sum), np.std(Cloud_UE_sum)]


x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x = x - width/2, height =  Batch_means, yerr = Batch_var,
                capsize = 3, width = width/4, label='Batch', color='orange')
rects2 = ax.bar(x = x - width/4, height = SG_means, yerr = SG_var, 
                capsize = 3, width = width/4, label='Seq-Greedy', color = 'green')
rects5 = ax.bar(x = x, height = Cloud_means, yerr = Cloud_var, 
                capsize = 3, width = width/4, label='Cloud', color = 'blue')
rects3 = ax.bar(x = x + width/4, height =  Myopic_means, yerr = Myopic_var,
                capsize = 3, width = width/4, label='Myopic', color='orange',hatch='//')
rects4 = ax.bar(x = x + width/2, height = Naive_means, yerr = Naive_var, 
                capsize = 3, width = width/4, label='Naive', color = 'green',hatch='//')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Monetary Cost (Dollars)')
ax.set_title('Heuristic and Baseline Sub-Cost')
ax.set_xticks(x)
# ax.set_xlabel('Cost Type')
ax.set_xticklabels(labels)
ax.legend()

# Set Y axis to zero
plt.ylim(0,)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Pickle Results For Reproduction
#
# Pickle the Sum values for later.

# %%
import pickle

cost_stores_dic = {}
cost_stores_dic["SG"] = SG_cost_stores
cost_stores_dic["Batch"] = Batch_cost_stores
cost_stores_dic["Naive"] = Naive_cost_stores
cost_stores_dic["Myopic"] = Myopic_cost_stores

pickle.dump(cost_stores_dic, open(os.path.curdir + "/sim_store/sim2/cost_store_v4.p", "wb" ) )

# %% [markdown]
# ### Run Same For Ample Resources

# %%
num_trials = 1
Batch_cost_stores_ample = []
SG_cost_stores_ample = []
Naive_cost_stores_ample = []
Myopic_cost_stores_ample = []
Cloud_cost_stores_ample = []

for i in range(num_trials):
    
    print("Trial Number:",i)
    
    # Make Users
    users, servers, links, jobs, sim_param = simulation_setting_ample()
    
    # Make Batch Prob
    
    print("batch_prob...")
    Batch_prob = SeqGreedy_PlanGenerator(users, servers, links, jobs, sim_param)
    Batch_plan = Migration_Plans(users,jobs,sim_param)
    Batch_plan.from_seq_greedy(Batch_prob)
    Batch_cost_stores_ample += [Cost_Recordings(Batch_plan)]
    print("done!")
    
    # Make SG Prob
    # Set Refresh to false for SG
    refresh_rate = [0,0]
    refresh = False

    for j in range(len(jobs)):
        jobs[j].info_from_usr(users[j],refresh_rate,refresh)
    
    print("SG prob...")
    SG_prob = SeqGreedy_PlanGenerator(users, servers, links, jobs, sim_param)
    SG_plan = Migration_Plans(users,jobs,sim_param)
    SG_plan.from_seq_greedy(SG_prob)
    SG_cost_stores_ample += [Cost_Recordings(SG_plan)]
    print("done!")
    
    # Make Cloud Prob
    print("Cloud prob...")
    Cloud_prob = Cloud_PlanGenerator(users, servers, links, jobs, sim_param)
    Cloud_plan = Migration_Plans(users,jobs,sim_param)
    Cloud_plan.from_seq_greedy(Cloud_prob)
    Cloud_cost_stores_ample += [Cost_Recordings(Cloud_plan)]
    print("done!")
    
    # Make Naive Prob
    print("Naive prob...")
    Naive_prob = Naive_PlanGenerator(users, servers, links, jobs, sim_param)
    Naive_plan = Migration_Plans(users,jobs,sim_param)
    Naive_plan.from_seq_greedy(Naive_prob)
    Naive_cost_stores_ample += [Cost_Recordings(Naive_plan)]
    print("done!")
    
    # Make Myopic Prob
    print("Myopic prob...")
    Myopic_prob = Myopic_PlanGenerator(users, servers, links, jobs, sim_param)
    Myopic_plan = Migration_Plans(users,jobs,sim_param)
    Myopic_plan.from_seq_greedy(Myopic_prob)
    Myopic_cost_stores_ample += [Cost_Recordings(Myopic_plan)]
    print("done!")

# %%
# Log the costs of interest
num_trials = len(Batch_cost_stores_ample)

SG_total_sum_ample = np.zeros(num_trials)

Batch_total_sum_ample = np.zeros(num_trials)

Myopic_total_sum_ample = np.zeros(num_trials)

Naive_total_sum_ample = np.zeros(num_trials)

Cloud_total_sum_ample = np.zeros(num_trials)

for i in range(num_trials):

    SG_total_sum_ample[i] += SG_cost_stores_ample[i].all_cost_cumulative["total_cost"][-1]

    Batch_total_sum_ample[i] += Batch_cost_stores_ample[i].all_cost_cumulative["total_cost"][-1]
    
    Myopic_total_sum_ample[i] += Myopic_cost_stores_ample[i].all_cost_cumulative["total_cost"][-1]
    
    Naive_total_sum_ample[i] += Naive_cost_stores_ample[i].all_cost_cumulative["total_cost"][-1]
    
    Cloud_total_sum_ample[i] += Cloud_cost_stores_ample[i].all_cost_cumulative["total_cost"][-1]

# %%
# Plot the plot
import matplotlib
import matplotlib.pyplot as plt

# Set Font Size Limitations
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 17}

matplotlib.rc('font', **font)

# Set Labels
labels = ['Batch', 'SG', 'Cloud', 'Myopic', 'Naive']

# Obtain Values to Plot
lim_means = [np.mean(Batch_total_sum), 
             np.mean(SG_total_sum),
             np.mean(Cloud_total_sum),
             np.mean(Myopic_total_sum),
            np.mean(Naive_total_sum)]

ample_means= [np.mean(Batch_total_sum_ample), 
             np.mean(SG_total_sum_ample),
             np.mean(Cloud_total_sum_ample),
             np.mean(Myopic_total_sum_ample),
             np.mean(Naive_total_sum_ample)]

lim_std = [np.std(Batch_total_sum),
           np.std(SG_total_sum), 
           np.std(Cloud_total_sum),
           np.std(Myopic_total_sum),
           np.std(Naive_total_sum)]

ample_std = [np.std(Batch_total_sum_ample), 
             np.std(SG_total_sum_ample),
             np.std(Cloud_total_sum_ample),
             np.std(Myopic_total_sum_ample),
             np.std(Naive_total_sum_ample)]



x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x = x-width/2, height =  lim_means, yerr = lim_std,
                capsize = 3, width = width, label='Limited', color='orange')
rects2 = ax.bar(x = x+width/2, height = ample_means, yerr = ample_std, 
                capsize = 3, width = width, label='Ample', color = 'green')


# Add some text for labels, title and custom x-axis tick labels, etc.
#ax.set_xlabel('Plan Type')
ax.set_ylabel('Monetary Cost (Dollars)')
ax.set_title('Plans Given System Resources')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Set Y axis to zero
plt.ylim(0,)

fig.tight_layout()

plt.show()

# %%
import pickle

cost_stores_dic = {}
cost_stores_dic["SG"] = SG_cost_stores_ample
cost_stores_dic["Batch"] = Batch_cost_stores_ample
cost_stores_dic["Naive"] = Naive_cost_stores_ample
cost_stores_dic["Myopic"] = Myopic_cost_stores_ample

pickle.dump(cost_stores_dic, open(os.path.curdir + "/sim_store/sim2/cost_store_ample_v3.p", "wb" ) )
